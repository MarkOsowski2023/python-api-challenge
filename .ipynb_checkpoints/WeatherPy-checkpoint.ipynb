# %% [markdown]
# # WeatherPy
# ----

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import json
from pprint import pprint
# Import API key
from config import weather_api_key
import scipy.stats as st

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 598

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Using OpenWeatherMap Direct Geocoding API
# Using For Loop to loop through cities
# Using a try/except block to determine which cities are found and not found
# storing the cities that are found in a list
# creating a dataframe with the information from the cities that are found
# print(cities)
# api call
# http://api.openweathermap.org/geo/1.0/direct?q={city}&limit={limit}&appid={API key}
url = 'http://api.openweathermap.org/geo/1.0/direct?q='
limit = 1
api_key = weather_api_key

weather_dict = {
    'city': cities,
    'lat': "",
    'lng': "",
}
weather_df = pd.DataFrame(weather_dict)
weather_df.head()

for city in cities:
    query_url = f'{url}{city}&limit={limit}&appid={api_key}'
    response = requests.get(query_url).json()
#     pprint(response)
    try:
        weather_df.loc[weather_df['city'] == city, 'lat'] = response[0]['lat']
        weather_df.loc[weather_df['city'] == city, 'lng'] = response[0]['lon']
        print(f'{city} found: processing data')
    except:
        print('City not found')
        pass
# Out:
# new norfolk found: processing data
# City not found
# hobart found: processing data
# ca mau found: processing data
# sayat found: processing data
# rikitea found: processing data
# jamestown found: processing data
# faanui found: processing data
# carauari found: processing data
# sohag found: processing data
# souillac found: processing data
# bengkulu found: processing data
# hofn found: processing data
# dikson found: processing data
# cayenne found: processing data
# umm durman found: processing data
# namwala found: processing data
# saint george found: processing data
# castro found: processing data
# norman wells found: processing data
# sola found: processing data
# barentsburg found: processing data
# kargasok found: processing data
# qaanaaq found: processing data
# tuatapere found: processing data
# butaritari found: processing data
# buta found: processing data
# thompson found: processing data
# mataura found: processing data
# mahebourg found: processing data
# port alfred found: processing data
# batagay found: processing data
# busselton found: processing data
# caravelas found: processing data
# City not found
# plettenberg bay found: processing data
# City not found
# tuktoyaktuk found: processing data
# kijang found: processing data
# bam found: processing data
# luganville found: processing data
# scottsbluff found: processing data
# hilo found: processing data
# bluff found: processing data
# timmins found: processing data
# ola found: processing data
# bredasdorp found: processing data
# manbij found: processing data
# vila velha found: processing data
# prince rupert found: processing data
# saldanha found: processing data
# lagoa found: processing data
# santa anita found: processing data
# kapaa found: processing data
# ushuaia found: processing data
# praia da vitoria found: processing data
# vila franca do campo found: processing data
# zhuhai found: processing data
# saskylakh found: processing data
# atuona found: processing data
# lichinga found: processing data
# sao filipe found: processing data
# luanda found: processing data
# shimoda found: processing data
# hermanus found: processing data
# tautira found: processing data
# umzimvubu found: processing data
# chokurdakh found: processing data
# cabo san lucas found: processing data
# guiratinga found: processing data
# bara found: processing data
# east london found: processing data
# City not found
# barrow found: processing data
# albany found: processing data
# mount gambier found: processing data
# tiksi found: processing data
# nikolskoye found: processing data
# duz found: processing data
# hithadhoo found: processing data
# puerto ayora found: processing data
# voyvozh found: processing data
# kaitangata found: processing data
# siteki found: processing data
# longyearbyen found: processing data
# alotau found: processing data
# pisco found: processing data
# ossora found: processing data
# alta floresta found: processing data
# bethel found: processing data
# taoudenni found: processing data
# cassilandia found: processing data
# belushya guba found: processing data
# yellowknife found: processing data
# nanortalik found: processing data
# saint-hyacinthe found: processing data
# kokopo found: processing data
# houston found: processing data
# illoqqortoormiut found: processing data
# kodiak found: processing data
# punta arenas found: processing data
# cape town found: processing data
# torbay found: processing data
# talnakh found: processing data
# skibbereen found: processing data
# yulara found: processing data
# chuy found: processing data
# iquique found: processing data
# aflu found: processing data
# petropavlovsk-kamchatskiy found: processing data
# muswellbrook found: processing data
# vangaindrano found: processing data
# oliver found: processing data
# namibe found: processing data
# vaini found: processing data
# springfield found: processing data
# veraval found: processing data
# libreville found: processing data
# City not found
# piacabucu found: processing data
# atbasar found: processing data
# kieta found: processing data
# jiddah found: processing data
# wuwei found: processing data
# celestun found: processing data
# satitoa found: processing data
# beroroha found: processing data
# erzin found: processing data
# City not found
# praia found: processing data
# bocas del toro found: processing data
# avarua found: processing data
# christchurch found: processing data
# westport found: processing data
# samusu found: processing data
# tsihombe found: processing data
# kununurra found: processing data
# ler found: processing data
# nelson bay found: processing data
# vaitupu found: processing data
# City not found
# namie found: processing data
# cumberland found: processing data
# indiana found: processing data
# City not found
# fort saint john found: processing data
# aksu found: processing data
# sao joao da barra found: processing data
# san vicente found: processing data
# mys shmidta found: processing data
# svetlogorsk found: processing data
# shingu found: processing data
# ndiekro found: processing data
# salym found: processing data
# coquimbo found: processing data
# kahului found: processing data
# tooele found: processing data
# akyab found: processing data
# ilulissat found: processing data
# kamenka found: processing data
# ampanihy found: processing data
# port hardy found: processing data
# vanimo found: processing data
# City not found
# City not found
# arraial do cabo found: processing data
# port elizabeth found: processing data
# sitka found: processing data
# seymchan found: processing data
# road town found: processing data
# isangel found: processing data
# takoradi found: processing data
# khatanga found: processing data
# leeton found: processing data
# trat found: processing data
# yumen found: processing data
# tuscaloosa found: processing data
# solnechnyy found: processing data
# bereda found: processing data
# tessalit found: processing data
# aykino found: processing data
# tasiilaq found: processing data
# City not found
# ponta do sol found: processing data
# orlik found: processing data
# san cristobal found: processing data
# feira de santana found: processing data
# bilma found: processing data
# lillooet found: processing data
# santhia found: processing data
# mar del plata found: processing data
# anito found: processing data
# City not found
# ornskoldsvik found: processing data
# haines junction found: processing data
# mareeba found: processing data
# alofi found: processing data
# santo antonio do ica found: processing data
# qandala found: processing data
# grindavik found: processing data
# vardo found: processing data
# bathsheba found: processing data
# balvi found: processing data
# bonavista found: processing data
# duzici found: processing data
# rawson found: processing data
# along found: processing data
# karaul found: processing data
# saleaula found: processing data
# inuvik found: processing data
# biak found: processing data
# umm lajj found: processing data
# whitehorse found: processing data
# torrington found: processing data
# grand river south east found: processing data
# chapais found: processing data
# zachagansk found: processing data
# skagastrond found: processing data
# hervey bay found: processing data
# kharp found: processing data
# havre-saint-pierre found: processing data
# buraydah found: processing data
# noumea found: processing data
# quatre cocos found: processing data
# falun found: processing data
# nanning found: processing data
# desaguadero found: processing data
# geraldton found: processing data
# san buenaventura found: processing data
# miles city found: processing data
# airai found: processing data
# victoria found: processing data
# tortoli found: processing data
# upernavik found: processing data
# mao found: processing data
# kewanee found: processing data
# prince george found: processing data
# valparaiso found: processing data
# dolbeau found: processing data
# thaton found: processing data
# ribeira grande found: processing data
# baruun-urt found: processing data
# provideniya found: processing data
# namatanai found: processing data
# faya found: processing data
# sakakah found: processing data
# soyo found: processing data
# savalou found: processing data
# honiara found: processing data
# City not found
# ambilobe found: processing data
# xuddur found: processing data
# cidreira found: processing data
# ust-nera found: processing data
# addis abeba found: processing data
# huarmey found: processing data
# kletnya found: processing data
# gornozavodsk found: processing data
# luderitz found: processing data
# awash found: processing data
# constitucion found: processing data
# shasta lake found: processing data
# guerrero negro found: processing data
# pirenopolis found: processing data
# pevek found: processing data
# City not found
# saint-pierre found: processing data
# evensk found: processing data
# elizabeth city found: processing data
# marcona found: processing data
# palauig found: processing data
# ponta delgada found: processing data
# nome found: processing data
# manturovo found: processing data
# tilichiki found: processing data
# aklavik found: processing data
# City not found
# mafinga found: processing data
# port hedland found: processing data
# qasigiannguit found: processing data
# City not found
# havoysund found: processing data
# zhezkazgan found: processing data
# waingapu found: processing data
# barra patuca found: processing data
# dingle found: processing data
# avera found: processing data
# bauchi found: processing data
# kavieng found: processing data
# sistranda found: processing data
# turbiv found: processing data
# victoria point found: processing data
# mackay found: processing data
# kruisfontein found: processing data
# katherine found: processing data
# rongcheng found: processing data
# lorengau found: processing data
# zhanaozen found: processing data
# kysyl-syr found: processing data
# nikolaevo found: processing data
# ancud found: processing data
# walvis bay found: processing data
# panguna found: processing data
# bertoua found: processing data
# kruszwica found: processing data
# carnarvon found: processing data
# romny found: processing data
# port blair found: processing data
# bogande found: processing data
# leningradskiy found: processing data
# clyde river found: processing data
# turukhansk found: processing data
# nazare found: processing data
# amderma found: processing data
# port lincoln found: processing data
# City not found
# roanoke rapids found: processing data
# san joaquin found: processing data
# nizhneyansk found: processing data
# whyalla found: processing data
# taman found: processing data
# mayo found: processing data
# menongue found: processing data
# dusti found: processing data
# thinadhoo found: processing data
# ostrovnoy found: processing data
# nemuro found: processing data
# longlac found: processing data
# birin found: processing data
# severo-kurilsk found: processing data
# santa cruz found: processing data
# vao found: processing data
# kulhudhuffushi found: processing data
# markova found: processing data
# boa vista found: processing data
# portland found: processing data
# viedma found: processing data
# olafsvik found: processing data
# verkhniye tatyshly found: processing data
# jacareacanga found: processing data
# te anau found: processing data
# padang found: processing data
# mezen found: processing data
# gorontalo found: processing data
# montijo found: processing data
# butajira found: processing data
# itaituba found: processing data
# talcahuano found: processing data
# salalah found: processing data
# bambous virieux found: processing data
# marsa matruh found: processing data
# ibiruba found: processing data
# puerto carreno found: processing data
# vallenar found: processing data
# lensk found: processing data
# nantucket found: processing data
# iqaluit found: processing data
# lavrentiya found: processing data
# carballo found: processing data
# vaitape found: processing data
# hammerfest found: processing data
# tsabong found: processing data
# humaita found: processing data
# bonthe found: processing data
# esperance found: processing data
# lagos found: processing data
# shelburne found: processing data
# sarakhs found: processing data
# coahuayana found: processing data
# san patricio found: processing data
# City not found
# west bay found: processing data
# kloulklubed found: processing data
# georgetown found: processing data
# mariel found: processing data
# saint-philippe found: processing data
# kochi found: processing data
# asau found: processing data
# hastings found: processing data
# yurla found: processing data
# masindi found: processing data
# ambulu found: processing data
# almaznyy found: processing data
# palmerston found: processing data
# fjerritslev found: processing data
# hambantota found: processing data
# mogadishu found: processing data
# kautokeino found: processing data
# sausar found: processing data
# komsomolskiy found: processing data
# City not found
# vila found: processing data
# lebu found: processing data
# kidal found: processing data
# ilka found: processing data
# santa rosalia found: processing data
# srednekolymsk found: processing data
# deputatskiy found: processing data
# bac lieu found: processing data
# bryan found: processing data
# pangnirtung found: processing data
# comodoro rivadavia found: processing data
# san juan found: processing data
# atherton found: processing data
# colares found: processing data
# north bend found: processing data
# City not found
# dunedin found: processing data
# san francisco de ojuera found: processing data
# buluang found: processing data
# rabo de peixe found: processing data
# santa rita found: processing data
# moundou found: processing data
# rocha found: processing data
# zambezi found: processing data
# kazalinsk found: processing data
# galiwinku found: processing data
# yanji found: processing data
# eureka found: processing data
# ferrol found: processing data
# vacaria found: processing data
# katsuura found: processing data
# san quintin found: processing data
# soe found: processing data
# goryachegorsk found: processing data
# poum found: processing data
# disa found: processing data
# moussoro found: processing data
# taltal found: processing data
# le port found: processing data
# sabang found: processing data
# broome found: processing data
# kibala found: processing data
# sokolo found: processing data
# soubre found: processing data
# berlevag found: processing data
# alvorada found: processing data
# winnemucca found: processing data
# kiri buru found: processing data
# beinamar found: processing data
# manokwari found: processing data
# sabzevar found: processing data
# labuhan found: processing data
# tabas found: processing data
# shadrinsk found: processing data
# rio grande found: processing data
# gamba found: processing data
# gizo found: processing data
# mariental found: processing data
# champerico found: processing data
# jinzhou found: processing data
# baykit found: processing data
# simbahan found: processing data
# huari found: processing data
# City not found
# saint-augustin found: processing data
# lasa found: processing data
# myaundzha found: processing data
# zakamensk found: processing data
# phek found: processing data
# bubaque found: processing data
# barahona found: processing data
# la primavera found: processing data
# rorvik found: processing data
# wanaka found: processing data
# college found: processing data
# sale found: processing data
# kambove found: processing data
# luau found: processing data
# gobabis found: processing data
# sioux lookout found: processing data
# sao felix do xingu found: processing data
# hualmay found: processing data
# roma found: processing data
# aitape found: processing data
# shenjiamen found: processing data
# calca found: processing data
# saint-joseph found: processing data
# timra found: processing data
# merauke found: processing data
# yamada found: processing data
# westpunt found: processing data
# igarape-miri found: processing data
# hornepayne found: processing data
# palora found: processing data
# erenhot found: processing data
# kungurtug found: processing data
# ahipara found: processing data
# kuliyapitiya found: processing data
# berbera found: processing data
# krasnoselkup found: processing data
# huanuco found: processing data
# bracebridge found: processing data
# louisbourg found: processing data
# masterton found: processing data
# hihya found: processing data
# nhulunbuy found: processing data
# boueni found: processing data
# ketchikan found: processing data
# oktyabrskiy found: processing data
# paamiut found: processing data
# puerto ayacucho found: processing data
# trairi found: processing data
# middleton found: processing data
# funadhoo found: processing data
# luangwa found: processing data
# georgiyevka found: processing data
# kalispell found: processing data
# bouca found: processing data
# terny found: processing data
# belyy yar found: processing data
# kjollefjord found: processing data
# hobyo found: processing data
# jahrom found: processing data
# elk city found: processing data
# itoman found: processing data
# adoni found: processing data
# altamira found: processing data
# andenes found: processing data
# brownsville found: processing data
# fare found: processing data
# ellisras found: processing data
# sarasota springs found: processing data
# smithers found: processing data
# bhikangaon found: processing data
# omsukchan found: processing data
# naze found: processing data
# sinnamary found: processing data
# nuuk found: processing data
# villa carlos paz found: processing data
# sorong found: processing data
# forrest city found: processing data
# City not found
# bababe found: processing data
# san luis found: processing data
# jalu found: processing data
# cap malheureux found: processing data
# oksfjord found: processing data
# upata found: processing data
# salinopolis found: processing data
# lichuan found: processing data
# paveh found: processing data
# vostok found: processing data
# poya found: processing data
# kavaratti found: processing data
# sidney found: processing data
# City not found
# maua found: processing data
# launceston found: processing data
# muisne found: processing data
# calabar found: processing data
# garowe found: processing data
# klyuchi found: processing data
# narsaq found: processing data
# kyren found: processing data
# senno found: processing data
# santa eulalia del rio found: processing data
# sijunjung found: processing data
# nikita found: processing data
# roebourne found: processing data
# pingxiang found: processing data
# coffs harbour found: processing data
# lompoc found: processing data
# kalamb found: processing data
# hasaki found: processing data
# sabha found: processing data
# benicarlo found: processing data
# matagami found: processing data
# phan rang found: processing data
# miri found: processing data
# kuche found: processing data
# baghdad found: processing data
# puerto cabello found: processing data
# banjar found: processing data
# ouahigouya found: processing data
# taiobeiras found: processing data
# olkhovka found: processing data
# saint anthony found: processing data
# aden found: processing data
# charagua found: processing data
# los llanos de aridane found: processing data
# marawi found: processing data
# banda aceh found: processing data
# berdigestyakh found: processing data
# City not found
# usta muhammad found: processing data
# sahrak found: processing data
# mount isa found: processing data
# dukat found: processing data
# tondano found: processing data
# kurumkan found: processing data
# wilmington found: processing data
# hami found: processing data
# yaan found: processing data
# warrington found: processing data
# ephrata found: processing data
# exu found: processing data
# pajapan found: processing data

# %%
weather_df.head()
# Out:
#           city      lat      lng
# 0  new norfolk -42.7802  147.062
# 1     tumannyy
# 2       hobart -42.8825  147.328
# 3       ca mau  9.17922  105.146
# 4        sayat  45.8273  3.05102

# %%
weather_df['max temperature'] = ""
weather_df['humidity'] = ""
weather_df['cloudiness'] = ""
weather_df['wind speed'] = ""
weather_df['country'] = ""
weather_df['date'] = ""
weather_df.head()
# Out:
#           city      lat      lng max temperature humidity cloudiness  \
# 0  new norfolk -42.7802  147.062
# 1     tumannyy
# 2       hobart -42.8825  147.328
# 3       ca mau  9.17922  105.146
# 4        sayat  45.8273  3.05102
#
#   wind speed country date
# 0
# 1
# 2
# 3
# 4

# %%
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid={API key}&units=imperial
units = 'imperial'
weather_url = 'https://api.openweathermap.org/data/2.5/weather?lat='

for city in cities:
    lat = weather_df.loc[weather_df['city'] == city, 'lat'].values[0]
    lon = weather_df.loc[weather_df['city'] == city, 'lng'].values[0]
    weather_query = f'{weather_url}{lat}&lon={lon}&appid={api_key}&units={units}'
    weather_response = requests.get(weather_query).json()
    
    try:
        weather_df.loc[weather_df['city'] == city, 'max temperature'] = weather_response['main']['temp_max']
        weather_df.loc[weather_df['city'] == city, 'humidity'] = weather_response['main']['humidity']
        weather_df.loc[weather_df['city'] == city, 'cloudiness'] = weather_response['clouds']['all']
        weather_df.loc[weather_df['city'] == city, 'wind speed'] = weather_response['wind']['speed']
        weather_df.loc[weather_df['city'] == city, 'country'] = weather_response['sys']['country']
        weather_df.loc[weather_df['city'] == city, 'date'] = weather_response['dt']
        print(f'Processing Weather Data For: {city}')
    except:
        print('No Data Reported')
        pass
# Out:
# Processing Weather Data For: new norfolk
# No Data Reported
# Processing Weather Data For: hobart
# Processing Weather Data For: ca mau
# Processing Weather Data For: sayat
# Processing Weather Data For: rikitea
# Processing Weather Data For: jamestown
# Processing Weather Data For: faanui
# Processing Weather Data For: carauari
# Processing Weather Data For: sohag
# Processing Weather Data For: souillac
# Processing Weather Data For: bengkulu
# Processing Weather Data For: hofn
# Processing Weather Data For: dikson
# Processing Weather Data For: cayenne
# Processing Weather Data For: umm durman
# Processing Weather Data For: namwala
# Processing Weather Data For: saint george
# Processing Weather Data For: castro
# Processing Weather Data For: norman wells
# Processing Weather Data For: sola
# Processing Weather Data For: barentsburg
# Processing Weather Data For: kargasok
# Processing Weather Data For: qaanaaq
# Processing Weather Data For: tuatapere
# Processing Weather Data For: butaritari
# Processing Weather Data For: buta
# Processing Weather Data For: thompson
# Processing Weather Data For: mataura
# Processing Weather Data For: mahebourg
# Processing Weather Data For: port alfred
# Processing Weather Data For: batagay
# Processing Weather Data For: busselton
# Processing Weather Data For: caravelas
# No Data Reported
# Processing Weather Data For: plettenberg bay
# No Data Reported
# Processing Weather Data For: tuktoyaktuk
# Processing Weather Data For: kijang
# Processing Weather Data For: bam
# Processing Weather Data For: luganville
# Processing Weather Data For: scottsbluff
# Processing Weather Data For: hilo
# Processing Weather Data For: bluff
# Processing Weather Data For: timmins
# Processing Weather Data For: ola
# Processing Weather Data For: bredasdorp
# Processing Weather Data For: manbij
# Processing Weather Data For: vila velha
# Processing Weather Data For: prince rupert
# Processing Weather Data For: saldanha
# Processing Weather Data For: lagoa
# Processing Weather Data For: santa anita
# Processing Weather Data For: kapaa
# Processing Weather Data For: ushuaia
# Processing Weather Data For: praia da vitoria
# Processing Weather Data For: vila franca do campo
# Processing Weather Data For: zhuhai
# Processing Weather Data For: saskylakh
# Processing Weather Data For: atuona
# Processing Weather Data For: lichinga
# Processing Weather Data For: sao filipe
# Processing Weather Data For: luanda
# Processing Weather Data For: shimoda
# Processing Weather Data For: hermanus
# Processing Weather Data For: tautira
# Processing Weather Data For: umzimvubu
# Processing Weather Data For: chokurdakh
# Processing Weather Data For: cabo san lucas
# Processing Weather Data For: guiratinga
# Processing Weather Data For: bara
# Processing Weather Data For: east london
# No Data Reported
# Processing Weather Data For: barrow
# Processing Weather Data For: albany
# Processing Weather Data For: mount gambier
# Processing Weather Data For: tiksi
# Processing Weather Data For: nikolskoye
# Processing Weather Data For: duz
# Processing Weather Data For: hithadhoo
# Processing Weather Data For: puerto ayora
# Processing Weather Data For: voyvozh
# Processing Weather Data For: kaitangata
# Processing Weather Data For: siteki
# Processing Weather Data For: longyearbyen
# Processing Weather Data For: alotau
# Processing Weather Data For: pisco
# Processing Weather Data For: ossora
# Processing Weather Data For: alta floresta
# Processing Weather Data For: bethel
# Processing Weather Data For: taoudenni
# Processing Weather Data For: cassilandia
# No Data Reported
# Processing Weather Data For: yellowknife
# Processing Weather Data For: nanortalik
# Processing Weather Data For: saint-hyacinthe
# Processing Weather Data For: kokopo
# Processing Weather Data For: houston
# Processing Weather Data For: illoqqortoormiut
# Processing Weather Data For: kodiak
# Processing Weather Data For: punta arenas
# Processing Weather Data For: cape town
# Processing Weather Data For: torbay
# Processing Weather Data For: talnakh
# Processing Weather Data For: skibbereen
# Processing Weather Data For: yulara
# Processing Weather Data For: chuy
# Processing Weather Data For: iquique
# Processing Weather Data For: aflu
# Processing Weather Data For: petropavlovsk-kamchatskiy
# Processing Weather Data For: muswellbrook
# Processing Weather Data For: vangaindrano
# Processing Weather Data For: oliver
# Processing Weather Data For: namibe
# Processing Weather Data For: vaini
# Processing Weather Data For: springfield
# Processing Weather Data For: veraval
# Processing Weather Data For: libreville
# No Data Reported
# Processing Weather Data For: piacabucu
# Processing Weather Data For: atbasar
# Processing Weather Data For: kieta
# Processing Weather Data For: jiddah
# Processing Weather Data For: wuwei
# Processing Weather Data For: celestun
# Processing Weather Data For: satitoa
# Processing Weather Data For: beroroha
# Processing Weather Data For: erzin
# No Data Reported
# Processing Weather Data For: praia
# Processing Weather Data For: bocas del toro
# Processing Weather Data For: avarua
# Processing Weather Data For: christchurch
# Processing Weather Data For: westport
# Processing Weather Data For: samusu
# Processing Weather Data For: tsihombe
# Processing Weather Data For: kununurra
# Processing Weather Data For: ler
# Processing Weather Data For: nelson bay
# Processing Weather Data For: vaitupu
# No Data Reported
# Processing Weather Data For: namie
# Processing Weather Data For: cumberland
# Processing Weather Data For: indiana
# No Data Reported
# Processing Weather Data For: fort saint john
# Processing Weather Data For: aksu
# Processing Weather Data For: sao joao da barra
# Processing Weather Data For: san vicente
# Processing Weather Data For: mys shmidta
# Processing Weather Data For: svetlogorsk
# Processing Weather Data For: shingu
# Processing Weather Data For: ndiekro
# Processing Weather Data For: salym
# Processing Weather Data For: coquimbo
# Processing Weather Data For: kahului
# Processing Weather Data For: tooele
# Processing Weather Data For: akyab
# Processing Weather Data For: ilulissat
# Processing Weather Data For: kamenka
# Processing Weather Data For: ampanihy
# Processing Weather Data For: port hardy
# Processing Weather Data For: vanimo
# No Data Reported
# No Data Reported
# Processing Weather Data For: arraial do cabo
# Processing Weather Data For: port elizabeth
# Processing Weather Data For: sitka
# Processing Weather Data For: seymchan
# Processing Weather Data For: road town
# Processing Weather Data For: isangel
# Processing Weather Data For: takoradi
# Processing Weather Data For: khatanga
# Processing Weather Data For: leeton
# Processing Weather Data For: trat
# Processing Weather Data For: yumen
# Processing Weather Data For: tuscaloosa
# Processing Weather Data For: solnechnyy
# Processing Weather Data For: bereda
# Processing Weather Data For: tessalit
# Processing Weather Data For: aykino
# Processing Weather Data For: tasiilaq
# No Data Reported
# Processing Weather Data For: ponta do sol
# Processing Weather Data For: orlik
# Processing Weather Data For: san cristobal
# Processing Weather Data For: feira de santana
# Processing Weather Data For: bilma
# Processing Weather Data For: lillooet
# Processing Weather Data For: santhia
# Processing Weather Data For: mar del plata
# Processing Weather Data For: anito
# No Data Reported
# Processing Weather Data For: ornskoldsvik
# Processing Weather Data For: haines junction
# Processing Weather Data For: mareeba
# Processing Weather Data For: alofi
# Processing Weather Data For: santo antonio do ica
# Processing Weather Data For: qandala
# Processing Weather Data For: grindavik
# Processing Weather Data For: vardo
# Processing Weather Data For: bathsheba
# Processing Weather Data For: balvi
# Processing Weather Data For: bonavista
# Processing Weather Data For: duzici
# Processing Weather Data For: rawson
# Processing Weather Data For: along
# Processing Weather Data For: karaul
# Processing Weather Data For: saleaula
# Processing Weather Data For: inuvik
# Processing Weather Data For: biak
# Processing Weather Data For: umm lajj
# Processing Weather Data For: whitehorse
# Processing Weather Data For: torrington
# Processing Weather Data For: grand river south east
# Processing Weather Data For: chapais
# Processing Weather Data For: zachagansk
# Processing Weather Data For: skagastrond
# Processing Weather Data For: hervey bay
# Processing Weather Data For: kharp
# Processing Weather Data For: havre-saint-pierre
# Processing Weather Data For: buraydah
# Processing Weather Data For: noumea
# Processing Weather Data For: quatre cocos
# Processing Weather Data For: falun
# Processing Weather Data For: nanning
# Processing Weather Data For: desaguadero
# Processing Weather Data For: geraldton
# Processing Weather Data For: san buenaventura
# Processing Weather Data For: miles city
# Processing Weather Data For: airai
# Processing Weather Data For: victoria
# Processing Weather Data For: tortoli
# Processing Weather Data For: upernavik
# Processing Weather Data For: mao
# Processing Weather Data For: kewanee
# Processing Weather Data For: prince george
# Processing Weather Data For: valparaiso
# Processing Weather Data For: dolbeau
# Processing Weather Data For: thaton
# Processing Weather Data For: ribeira grande
# Processing Weather Data For: baruun-urt
# Processing Weather Data For: provideniya
# Processing Weather Data For: namatanai
# Processing Weather Data For: faya
# Processing Weather Data For: sakakah
# Processing Weather Data For: soyo
# Processing Weather Data For: savalou
# Processing Weather Data For: honiara
# No Data Reported
# Processing Weather Data For: ambilobe
# Processing Weather Data For: xuddur
# Processing Weather Data For: cidreira
# Processing Weather Data For: ust-nera
# Processing Weather Data For: addis abeba
# Processing Weather Data For: huarmey
# Processing Weather Data For: kletnya
# Processing Weather Data For: gornozavodsk
# Processing Weather Data For: luderitz
# Processing Weather Data For: awash
# Processing Weather Data For: constitucion
# Processing Weather Data For: shasta lake
# Processing Weather Data For: guerrero negro
# Processing Weather Data For: pirenopolis
# Processing Weather Data For: pevek
# No Data Reported
# Processing Weather Data For: saint-pierre
# Processing Weather Data For: evensk
# Processing Weather Data For: elizabeth city
# Processing Weather Data For: marcona
# Processing Weather Data For: palauig
# Processing Weather Data For: ponta delgada
# Processing Weather Data For: nome
# Processing Weather Data For: manturovo
# Processing Weather Data For: tilichiki
# Processing Weather Data For: aklavik
# No Data Reported
# Processing Weather Data For: mafinga
# Processing Weather Data For: port hedland
# Processing Weather Data For: qasigiannguit
# No Data Reported
# Processing Weather Data For: havoysund
# Processing Weather Data For: zhezkazgan
# Processing Weather Data For: waingapu
# Processing Weather Data For: barra patuca
# Processing Weather Data For: dingle
# Processing Weather Data For: avera
# Processing Weather Data For: bauchi
# Processing Weather Data For: kavieng
# Processing Weather Data For: sistranda
# Processing Weather Data For: turbiv
# Processing Weather Data For: victoria point
# Processing Weather Data For: mackay
# Processing Weather Data For: kruisfontein
# Processing Weather Data For: katherine
# Processing Weather Data For: rongcheng
# Processing Weather Data For: lorengau
# Processing Weather Data For: zhanaozen
# Processing Weather Data For: kysyl-syr
# Processing Weather Data For: nikolaevo
# Processing Weather Data For: ancud
# Processing Weather Data For: walvis bay
# Processing Weather Data For: panguna
# Processing Weather Data For: bertoua
# Processing Weather Data For: kruszwica
# Processing Weather Data For: carnarvon
# Processing Weather Data For: romny
# Processing Weather Data For: port blair
# Processing Weather Data For: bogande
# Processing Weather Data For: leningradskiy
# Processing Weather Data For: clyde river
# Processing Weather Data For: turukhansk
# Processing Weather Data For: nazare
# Processing Weather Data For: amderma
# Processing Weather Data For: port lincoln
# No Data Reported
# Processing Weather Data For: roanoke rapids
# Processing Weather Data For: san joaquin
# Processing Weather Data For: nizhneyansk
# Processing Weather Data For: whyalla
# Processing Weather Data For: taman
# Processing Weather Data For: mayo
# Processing Weather Data For: menongue
# Processing Weather Data For: dusti
# Processing Weather Data For: thinadhoo
# Processing Weather Data For: ostrovnoy
# Processing Weather Data For: nemuro
# Processing Weather Data For: longlac
# Processing Weather Data For: birin
# Processing Weather Data For: severo-kurilsk
# Processing Weather Data For: santa cruz
# Processing Weather Data For: vao
# Processing Weather Data For: kulhudhuffushi
# Processing Weather Data For: markova
# Processing Weather Data For: boa vista
# Processing Weather Data For: portland
# Processing Weather Data For: viedma
# Processing Weather Data For: olafsvik
# Processing Weather Data For: verkhniye tatyshly
# Processing Weather Data For: jacareacanga
# Processing Weather Data For: te anau
# Processing Weather Data For: padang
# Processing Weather Data For: mezen
# Processing Weather Data For: gorontalo
# Processing Weather Data For: montijo
# Processing Weather Data For: butajira
# Processing Weather Data For: itaituba
# Processing Weather Data For: talcahuano
# Processing Weather Data For: salalah
# Processing Weather Data For: bambous virieux
# Processing Weather Data For: marsa matruh
# Processing Weather Data For: ibiruba
# Processing Weather Data For: puerto carreno
# Processing Weather Data For: vallenar
# Processing Weather Data For: lensk
# Processing Weather Data For: nantucket
# Processing Weather Data For: iqaluit
# Processing Weather Data For: lavrentiya
# Processing Weather Data For: carballo
# Processing Weather Data For: vaitape
# Processing Weather Data For: hammerfest
# Processing Weather Data For: tsabong
# Processing Weather Data For: humaita
# Processing Weather Data For: bonthe
# Processing Weather Data For: esperance
# Processing Weather Data For: lagos
# Processing Weather Data For: shelburne
# Processing Weather Data For: sarakhs
# Processing Weather Data For: coahuayana
# Processing Weather Data For: san patricio
# No Data Reported
# Processing Weather Data For: west bay
# Processing Weather Data For: kloulklubed
# Processing Weather Data For: georgetown
# Processing Weather Data For: mariel
# Processing Weather Data For: saint-philippe
# Processing Weather Data For: kochi
# Processing Weather Data For: asau
# Processing Weather Data For: hastings
# Processing Weather Data For: yurla
# Processing Weather Data For: masindi
# Processing Weather Data For: ambulu
# Processing Weather Data For: almaznyy
# No Data Reported
# Processing Weather Data For: fjerritslev
# Processing Weather Data For: hambantota
# Processing Weather Data For: mogadishu
# Processing Weather Data For: kautokeino
# Processing Weather Data For: sausar
# Processing Weather Data For: komsomolskiy
# No Data Reported
# Processing Weather Data For: vila
# Processing Weather Data For: lebu
# Processing Weather Data For: kidal
# Processing Weather Data For: ilka
# Processing Weather Data For: santa rosalia
# Processing Weather Data For: srednekolymsk
# Processing Weather Data For: deputatskiy
# Processing Weather Data For: bac lieu
# Processing Weather Data For: bryan
# Processing Weather Data For: pangnirtung
# Processing Weather Data For: comodoro rivadavia
# Processing Weather Data For: san juan
# Processing Weather Data For: atherton
# Processing Weather Data For: colares
# Processing Weather Data For: north bend
# No Data Reported
# Processing Weather Data For: dunedin
# Processing Weather Data For: san francisco de ojuera
# Processing Weather Data For: buluang
# Processing Weather Data For: rabo de peixe
# Processing Weather Data For: santa rita
# Processing Weather Data For: moundou
# Processing Weather Data For: rocha
# Processing Weather Data For: zambezi
# Processing Weather Data For: kazalinsk
# Processing Weather Data For: galiwinku
# Processing Weather Data For: yanji
# Processing Weather Data For: eureka
# Processing Weather Data For: ferrol
# Processing Weather Data For: vacaria
# Processing Weather Data For: katsuura
# Processing Weather Data For: san quintin
# Processing Weather Data For: soe
# Processing Weather Data For: goryachegorsk
# Processing Weather Data For: poum
# Processing Weather Data For: disa
# Processing Weather Data For: moussoro
# Processing Weather Data For: taltal
# Processing Weather Data For: le port
# Processing Weather Data For: sabang
# Processing Weather Data For: broome
# Processing Weather Data For: kibala
# Processing Weather Data For: sokolo
# Processing Weather Data For: soubre
# Processing Weather Data For: berlevag
# Processing Weather Data For: alvorada
# Processing Weather Data For: winnemucca
# Processing Weather Data For: kiri buru
# Processing Weather Data For: beinamar
# Processing Weather Data For: manokwari
# Processing Weather Data For: sabzevar
# Processing Weather Data For: labuhan
# Processing Weather Data For: tabas
# Processing Weather Data For: shadrinsk
# Processing Weather Data For: rio grande
# Processing Weather Data For: gamba
# Processing Weather Data For: gizo
# Processing Weather Data For: mariental
# Processing Weather Data For: champerico
# Processing Weather Data For: jinzhou
# Processing Weather Data For: baykit
# Processing Weather Data For: simbahan
# Processing Weather Data For: huari
# No Data Reported
# Processing Weather Data For: saint-augustin
# Processing Weather Data For: lasa
# Processing Weather Data For: myaundzha
# Processing Weather Data For: zakamensk
# Processing Weather Data For: phek
# Processing Weather Data For: bubaque
# Processing Weather Data For: barahona
# Processing Weather Data For: la primavera
# Processing Weather Data For: rorvik
# Processing Weather Data For: wanaka
# Processing Weather Data For: college
# Processing Weather Data For: sale
# Processing Weather Data For: kambove
# Processing Weather Data For: luau
# Processing Weather Data For: gobabis
# Processing Weather Data For: sioux lookout
# Processing Weather Data For: sao felix do xingu
# Processing Weather Data For: hualmay
# Processing Weather Data For: roma
# Processing Weather Data For: aitape
# Processing Weather Data For: shenjiamen
# Processing Weather Data For: calca
# Processing Weather Data For: saint-joseph
# Processing Weather Data For: timra
# Processing Weather Data For: merauke
# Processing Weather Data For: yamada
# Processing Weather Data For: westpunt
# Processing Weather Data For: igarape-miri
# Processing Weather Data For: hornepayne
# Processing Weather Data For: palora
# Processing Weather Data For: erenhot
# Processing Weather Data For: kungurtug
# Processing Weather Data For: ahipara
# Processing Weather Data For: kuliyapitiya
# Processing Weather Data For: berbera
# Processing Weather Data For: krasnoselkup
# Processing Weather Data For: huanuco
# Processing Weather Data For: bracebridge
# Processing Weather Data For: louisbourg
# Processing Weather Data For: masterton
# Processing Weather Data For: hihya
# Processing Weather Data For: nhulunbuy
# Processing Weather Data For: boueni
# Processing Weather Data For: ketchikan
# Processing Weather Data For: oktyabrskiy
# Processing Weather Data For: paamiut
# Processing Weather Data For: puerto ayacucho
# Processing Weather Data For: trairi
# Processing Weather Data For: middleton
# Processing Weather Data For: funadhoo
# Processing Weather Data For: luangwa
# Processing Weather Data For: georgiyevka
# Processing Weather Data For: kalispell
# Processing Weather Data For: bouca
# Processing Weather Data For: terny
# Processing Weather Data For: belyy yar
# Processing Weather Data For: kjollefjord
# Processing Weather Data For: hobyo
# Processing Weather Data For: jahrom
# Processing Weather Data For: elk city
# Processing Weather Data For: itoman
# Processing Weather Data For: adoni
# Processing Weather Data For: altamira
# Processing Weather Data For: andenes
# Processing Weather Data For: brownsville
# Processing Weather Data For: fare
# Processing Weather Data For: ellisras
# Processing Weather Data For: sarasota springs
# Processing Weather Data For: smithers
# Processing Weather Data For: bhikangaon
# Processing Weather Data For: omsukchan
# Processing Weather Data For: naze
# Processing Weather Data For: sinnamary
# Processing Weather Data For: nuuk
# Processing Weather Data For: villa carlos paz
# Processing Weather Data For: sorong
# Processing Weather Data For: forrest city
# No Data Reported
# Processing Weather Data For: bababe
# Processing Weather Data For: san luis
# Processing Weather Data For: jalu
# Processing Weather Data For: cap malheureux
# Processing Weather Data For: oksfjord
# Processing Weather Data For: upata
# Processing Weather Data For: salinopolis
# Processing Weather Data For: lichuan
# Processing Weather Data For: paveh
# No Data Reported
# Processing Weather Data For: poya
# Processing Weather Data For: kavaratti
# Processing Weather Data For: sidney
# No Data Reported
# Processing Weather Data For: maua
# Processing Weather Data For: launceston
# Processing Weather Data For: muisne
# Processing Weather Data For: calabar
# Processing Weather Data For: garowe
# Processing Weather Data For: klyuchi
# Processing Weather Data For: narsaq
# Processing Weather Data For: kyren
# Processing Weather Data For: senno
# Processing Weather Data For: santa eulalia del rio
# Processing Weather Data For: sijunjung
# Processing Weather Data For: nikita
# Processing Weather Data For: roebourne
# Processing Weather Data For: pingxiang
# Processing Weather Data For: coffs harbour
# Processing Weather Data For: lompoc
# Processing Weather Data For: kalamb
# Processing Weather Data For: hasaki
# Processing Weather Data For: sabha
# Processing Weather Data For: benicarlo
# Processing Weather Data For: matagami
# Processing Weather Data For: phan rang
# Processing Weather Data For: miri
# Processing Weather Data For: kuche
# Processing Weather Data For: baghdad
# Processing Weather Data For: puerto cabello
# Processing Weather Data For: banjar
# Processing Weather Data For: ouahigouya
# Processing Weather Data For: taiobeiras
# Processing Weather Data For: olkhovka
# Processing Weather Data For: saint anthony
# Processing Weather Data For: aden
# Processing Weather Data For: charagua
# Processing Weather Data For: los llanos de aridane
# Processing Weather Data For: marawi
# Processing Weather Data For: banda aceh
# Processing Weather Data For: berdigestyakh
# No Data Reported
# Processing Weather Data For: usta muhammad
# Processing Weather Data For: sahrak
# Processing Weather Data For: mount isa
# Processing Weather Data For: dukat
# Processing Weather Data For: tondano
# Processing Weather Data For: kurumkan
# Processing Weather Data For: wilmington
# Processing Weather Data For: hami
# Processing Weather Data For: yaan
# Processing Weather Data For: warrington
# Processing Weather Data For: ephrata
# Processing Weather Data For: exu
# Processing Weather Data For: pajapan

# %%
# Cleaning the dataframe
# check counts()
weather_df.head()
print(weather_df.count())
print('-----------------------------------')
# drop all row with missing weather data
# replace rows "" -empty spaces with nan
# dropna
weather_df.replace("", np.nan, inplace=True)
clean_df = weather_df.dropna(how='any')
print(clean_df.count())
# Out:
# city               598
# lat                598
# lng                598
# max temperature    598
# humidity           598
# cloudiness         598
# wind speed         598
# country            598
# date               598
# dtype: int64
# -----------------------------------
# city               571
# lat                571
# lng                571
# max temperature    571
# humidity           571
# cloudiness         571
# wind speed         571
# country            571
# date               571
# dtype: int64

# %%
# Droping the extra temperature series that is still there from earlier, keeping max temperatuure series
# clean_df.drop('temperature', axis=1, inplace=True)
clean_df.head()
# Out:
#           city        lat         lng  max temperature  humidity  cloudiness  \
# 0  new norfolk -42.780200  147.061533            60.53      51.0         3.0
# 2       hobart -42.882509  147.328123            60.60      62.0        20.0
# 3       ca mau   9.179222  105.145791            83.16      77.0       100.0
# 4        sayat  45.827315    3.051024            73.42      46.0         0.0
# 5      rikitea -23.122954 -134.968014            71.80      72.0        93.0
#
#    wind speed country          date
# 0        9.22      AU  1.659577e+09
# 2        8.05      AU  1.659577e+09
# 3        7.07      VN  1.659577e+09
# 4        1.14      FR  1.659577e+09
# 5       18.68      PF  1.659577e+09

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# dataframe to csv
clean_df.to_csv(output_data_file, encoding='utf-8', index=False)

# %%
clean_df
# Out:
#             city        lat         lng  max temperature  humidity  \
# 0    new norfolk -42.780200  147.061533            60.53      51.0
# 2         hobart -42.882509  147.328123            60.60      62.0
# 3         ca mau   9.179222  105.145791            83.16      77.0
# 4          sayat  45.827315    3.051024            73.42      46.0
# 5        rikitea -23.122954 -134.968014            71.80      72.0
# ..           ...        ...         ...              ...       ...
# 593         yaan  29.985931  103.008794            82.11      82.0
# 594   warrington  53.389950   -2.594318            62.74      85.0
# 595      ephrata  40.179911  -76.178924            80.40      65.0
# 596          exu  -7.515434  -39.722015            67.44      88.0
# 597      pajapan  18.262065  -94.691598            76.24      86.0
#
#      cloudiness  wind speed country          date
# 0           3.0        9.22      AU  1.659577e+09
# 2          20.0        8.05      AU  1.659577e+09
# 3         100.0        7.07      VN  1.659577e+09
# 4           0.0        1.14      FR  1.659577e+09
# 5          93.0       18.68      PF  1.659577e+09
# ..          ...         ...     ...           ...
# 593        13.0        0.76      CN  1.659578e+09
# 594        75.0       12.66      GB  1.659578e+09
# 595         0.0        5.95      US  1.659577e+09
# 596        93.0        6.89      BR  1.659578e+09
# 597         0.0        6.91      MX  1.659578e+09
#
# [571 rows x 9 columns]

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
# .loc[] humidity > 100
print(clean_df.loc[clean_df['humidity'] > 100].head())
# Out:
# Empty DataFrame
# Columns: [city, lat, lng, max temperature, humidity, cloudiness, wind speed, country, date]
# Index: []

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# using plt.scatter
# x and y axis
x_lat = clean_df['lat']
max_temp = clean_df['max temperature']
plt.scatter(x_lat, max_temp, marker='o', facecolors='Red', edgecolors='black', s=50, alpha=0.85)
plt.grid()
plt.title(f'Max Temperature vs. Latitude')
plt.ylabel('Max Temperature (F)')
plt.xlabel('Latitude')
# Out:
# Text(0.5, 0, 'Latitude')

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
y_hum = clean_df['humidity']
plt.scatter(x_lat, y_hum, marker='o', facecolors='Green', edgecolors='black', s=50, alpha=0.85)
plt.title('Humidity vs. Latitude')
plt.ylabel('Humidity (%)')
plt.xlabel('Latitude')
plt.grid()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
y_cloud = clean_df['cloudiness']
plt.scatter(x_lat, y_cloud, marker='o', facecolors="deepskyblue", edgecolors='black', s=50, alpha=0.8)
plt.grid()
plt.title('Cloudiness vs. Latitude')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
# Out:
# Text(0, 0.5, 'Cloudiness (%)')

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
y_wind = clean_df['wind speed']
plt.scatter(x_lat, y_wind, marker='o', facecolors="lightsteelblue", edgecolors='black', s=50, alpha=0.85)
plt.grid()
plt.title('Wind Speed vs. Latitude')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
# Out:
# Text(0, 0.5, 'Wind Speed (mph)')

# %% [markdown]
# ## Linear Regression

# %%
# Creating seperate dataframes for Northern and Southern Hemisphere
# using .loc
# print results
n_hemisphere_data = clean_df.loc[clean_df['lat'] >= 0]
print('Northern Hemisphere')
print('----------------------------')
print(n_hemisphere_data.head())
print(n_hemisphere_data.count())
print('---------------------------')
print('Southern Hemisphere')
print('-----------------------------')
s_hemisphere_data = clean_df.loc[clean_df['lat'] < 0]
print(s_hemisphere_data.head())
print(s_hemisphere_data.count())
# Out:
# Northern Hemisphere
# ----------------------------
#          city        lat         lng  max temperature  humidity  cloudiness  \
# 3      ca mau   9.179222  105.145791            83.16      77.0       100.0
# 4       sayat  45.827315    3.051024            73.42      46.0         0.0
# 6   jamestown  37.210443  -76.773893            84.20      89.0         0.0
# 9       sohag  26.547748   31.699263            82.67      30.0         5.0
# 10   souillac  44.898017    1.469430            69.66      50.0        53.0
#
#     wind speed country          date
# 3         7.07      VN  1.659577e+09
# 4         1.14      FR  1.659577e+09
# 6         3.44      US  1.659577e+09
# 9         8.57      EG  1.659577e+09
# 10        4.59      FR  1.659577e+09
# city               395
# lat                395
# lng                395
# max temperature    395
# humidity           395
# cloudiness         395
# wind speed         395
# country            395
# date               395
# dtype: int64
# ---------------------------
# Southern Hemisphere
# -----------------------------
#           city        lat         lng  max temperature  humidity  cloudiness  \
# 0  new norfolk -42.780200  147.061533            60.53      51.0         3.0
# 2       hobart -42.882509  147.328123            60.60      62.0        20.0
# 5      rikitea -23.122954 -134.968014            71.80      72.0        93.0
# 7       faanui -16.482439 -151.733832            77.52      75.0        17.0
# 8     carauari  -4.876643  -66.896143            77.83      77.0        83.0
#
#    wind speed country          date
# 0        9.22      AU  1.659577e+09
# 2        8.05      AU  1.659577e+09
# 5       18.68      PF  1.659577e+09
# 7       22.70      PF  1.659577e+09
# 8        0.45      BR  1.659577e+09
# city               176
# lat                176
# lng                176
# max temperature    176
# humidity           176
# cloudiness         176
# wind speed         176
# country            176
# date               176
# dtype: int64

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# values for regression
print('Northern Hemisphere - Max Temp vs. Latitude Linear Regression')
# x value (north hemisphere latitudes)
x_nh_lat = n_hemisphere_data['lat']
# y value (north hemispher max temps)
y_nh_maxtemp = n_hemisphere_data['max temperature']

# regression values (slope, intercept, rvalue, pvalue, stderr)
nh_mt_slope, nh_mt_int, nh_mt_r, nh_mt_p, nh_mt_stderr = linregress(x_nh_lat, y_nh_maxtemp)
nh_mt_fit = nh_mt_slope * x_nh_lat + nh_mt_int
nh_mt_eq = f'y = {round(nh_mt_slope,2)}x + {round(nh_mt_int,2)}'
print(f'Linear Regression Equation: {nh_mt_eq}')
nh_mt_correlation = st.pearsonr(x_nh_lat,y_nh_maxtemp)
print(f'Correlation: {nh_mt_correlation[0]}')

# plotting

# scatter
plt.scatter(x_nh_lat, y_nh_maxtemp, marker='o', facecolors='firebrick', edgecolors='black', s=50, alpha=0.75)
plt.grid()
plt.title('Northern Hemisphere - Max Temp vs. Latitude')
plt.xlabel('Latitude')
plt.ylabel('Max Temp (F)')

# plotting equation line
plt.plot(x_nh_lat, nh_mt_fit, 'k--')
plt.annotate(nh_mt_eq, (10,40))
# Out:
# Northern Hemisphere - Max Temp vs. Latitude Linear Regression
# Linear Regression Equation: y = -0.39x + 86.12
# Correlation: -0.6420797623616936
# Text(10, 40, 'y = -0.39x + 86.12')

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
print('Southern Hemisphere - Max Temp vs. Latitude Linear Regression')
# values
# x - south hem latitude
x_sh_lat = s_hemisphere_data['lat']

# y - south hem max temp
y_sh_maxtemp = s_hemisphere_data['max temperature']

# regression values
sh_mt_slope, sh_mt_int, sh_mt_r, sh_mt_p, sh_mt_stderr = linregress(x_sh_lat, y_sh_maxtemp)
# fit
sh_mt_fit = sh_mt_slope * x_sh_lat + sh_mt_int

# equation
sh_mt_eq = f'y = {round(sh_mt_slope,2)}x + {round(sh_mt_int,2)}'
print(f'Linear Regression Equation: {sh_mt_eq}')

# correlation
sh_mt_correlation = st.pearsonr(x_sh_lat,y_sh_maxtemp)
print(f'Correlation: {sh_mt_correlation[0]}')

# Plotting
# scatter
plt.scatter(x_sh_lat, y_sh_maxtemp, marker='o', facecolors='red', edgecolors='black', s=50, alpha=0.75)
plt.grid()
plt.title('Southern Hemisphere - Max Temp vs. Latitude')
plt.xlabel('Latitude')
plt.ylabel('Max Temp (F)')

# regression line
plt.plot(x_sh_lat, sh_mt_fit, 'k--')
plt.annotate(sh_mt_eq, (-20,40))
# Out:
# Southern Hemisphere - Max Temp vs. Latitude Linear Regression
# Linear Regression Equation: y = 0.63x + 79.03
# Correlation: 0.6894415600194802
# Text(-20, 40, 'y = 0.63x + 79.03')

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
print('Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression')

# values
# x already x nh lat
# y - north hem humidity
y_nh_humidity = n_hemisphere_data['humidity']

# regression values
nh_h_slope, nh_h_int, nh_h_r, nh_h_p, nh_h_stderr = linregress(x_nh_lat, y_nh_humidity)
# fit
nh_h_fit = nh_h_slope * x_nh_lat + nh_h_int

# equation
nh_h_eq = f'y = {round(nh_h_slope,2)}x + {round(nh_h_int,2)}'
print(f'Linear Regression Equation: {nh_h_eq}')

# correlation
nh_h_corr = st.pearsonr(x_nh_lat,y_nh_humidity)
print(f'Correlation: {nh_h_corr[0]}')

# plotting
# scatter
plt.scatter(x_nh_lat, y_nh_humidity, marker='o', facecolors='green', edgecolors='black', s=50, alpha=0.75)
plt.grid()
plt.title('Northern Hemisphere - Humidity (%) vs. Latitude')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')

# regression line
plt.plot(x_nh_lat, nh_h_fit, 'k--')
plt.annotate(nh_h_eq, (60,20))
# Out:
# Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression
# Linear Regression Equation: y = -0.06x + 74.81
# Correlation: -0.06406354780690346
# Text(60, 20, 'y = -0.06x + 74.81')

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
print('Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression')

# values
# already have x sh lat
# y - south hem humidity
y_sh_humidity = s_hemisphere_data['humidity']

# regression values
sh_h_slope, sh_h_int, sh_h_r, sh_h_p, sh_h_stderr = linregress(x_sh_lat, y_sh_humidity)
# fit
sh_h_fit = sh_h_slope * x_sh_lat + sh_h_int

# equation
sh_h_eq = f'y = {round(sh_h_slope,2)}x + {round(sh_h_int,2)}'
print(f'Linear Regression Equation: {sh_h_eq}')

# correlation
sh_h_corr = st.pearsonr(x_sh_lat,y_sh_humidity)
print(f'Correlation: {sh_h_corr[0]}')

# plotting
# scatter
plt.scatter(x_sh_lat, y_sh_humidity, marker='o', facecolors='green', edgecolors='black', s=50, alpha=0.75)
plt.grid()
plt.title('Southern Hemisphere - Humidity (%) vs. Latitude')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')

# plot regression
plt.plot(x_sh_lat, sh_h_fit, 'k--')
plt.annotate(sh_h_eq, (-50,40))
# Out:
# Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression
# Linear Regression Equation: y = 0.02x + 74.5
# Correlation: 0.02075087113344301
# Text(-50, 40, 'y = 0.02x + 74.5')

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
print('Northern Hemisphere - Cloudiness (%) vs. Latitude')

# values
# x nh lat
# y - north hem cloudiness
y_nh_cloud = n_hemisphere_data['cloudiness']

# regess values
nh_c_slope, nh_c_int, nh_c_r, nh_c_p, nh_c_stderr = linregress(x_nh_lat, y_nh_cloud)
# fit
nh_c_fit = nh_c_slope * x_nh_lat + nh_c_int

# equation
nh_c_eq = f'y = {round(nh_c_slope,2)}x + {round(nh_c_int)}'
print(f'Linear Regression Equation: {nh_c_eq}')

# correlation
nh_c_corr = st.pearsonr(x_nh_lat,y_nh_cloud)
print(f'Correlation: {nh_c_corr[0]}')

# plotting
# scatter
plt.scatter(x_nh_lat, y_nh_cloud, marker='o', facecolors='deepskyblue', edgecolors='black', s=50, alpha=0.75)
plt.grid()
plt.title('Northern Hemisphere - Cloudiness (%) vs. Latitude')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')

# regrss line
plt.plot(x_nh_lat, nh_c_fit, "k--")
plt.annotate(nh_c_eq, (0,45))
# Out:
# Northern Hemisphere - Cloudiness (%) vs. Latitude
# Linear Regression Equation: y = -0.1x + 56.0
# Correlation: -0.050220965856134475
# Text(0, 45, 'y = -0.1x + 56.0')

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
print('Southern Hemisphere - Cloudiness (%) vs. Latitude')

# values
# x sh lat
# y - south hem cloudiness
y_sh_cloud = s_hemisphere_data['cloudiness']

# regress values
sh_c_slope, sh_c_int, sh_c_r, sh_c_p, sh_c_stderr = linregress(x_sh_lat, y_sh_cloud)
# fit
sh_c_fit = sh_c_slope * x_sh_lat + sh_c_int

# equation
sh_c_eq = f'y = {round(sh_c_slope,2)}x + {round(sh_c_int)}'
print(f'Linear Regression Equation: {sh_c_eq}')

# correlation
sh_c_corr = st.pearsonr(x_sh_lat,y_sh_cloud)
print(f'Correlation: {sh_c_corr[0]}')

# plotting
# scatter
plt.scatter(x_sh_lat, y_sh_cloud, marker='o', facecolors='deepskyblue', edgecolors='black', s=50, alpha=0.75)
plt.grid()
plt.title('Southern Hemisphere - Cloudiness (%) vs. Latitude')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')

# regress line
plt.plot(x_sh_lat, sh_c_fit, 'k--')
plt.annotate(sh_c_eq, (-50, 45))
# Out:
# Southern Hemisphere - Cloudiness (%) vs. Latitude
# Linear Regression Equation: y = -0.04x + 48.0
# Correlation: -0.01304882203833997
# Text(-50, 45, 'y = -0.04x + 48.0')

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
print('Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression')

# values
# x nh lat
# y - north hem wind speed
y_nh_wind = n_hemisphere_data['wind speed']

# regress values
nh_ws_slope, nh_ws_int, nh_ws_r, nh_ws_p, nh_ws_stderr = linregress(x_nh_lat, y_nh_wind)
# fit
nh_ws_fit = nh_ws_slope * x_nh_lat + nh_ws_int

# equation
nh_ws_eq = f'y = {round(nh_ws_slope,2)}x + {round(nh_ws_int,2)}'
print(f'Linear Regression Equation: {nh_ws_eq}')

# correlation
nh_ws_corr = st.pearsonr(x_nh_lat,y_nh_wind)
print(f'Correlaton: {nh_ws_corr[0]}')

# plotting
# scatter
plt.scatter(x_nh_lat, y_nh_wind, marker='o', facecolors='lightsteelblue', edgecolors='black', s=50, alpha=0.75)
plt.grid()
plt.title('Northern Hemisphere - Wind Speed (mph) vs. Latitude')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')

# regress line
plt.plot(x_nh_lat, nh_ws_fit, 'k--')
plt.annotate(nh_ws_eq, (10, 31))
# Out:
# Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
# Linear Regression Equation: y = -0.01x + 8.25
# Correlaton: -0.05500860400964842
# Text(10, 31, 'y = -0.01x + 8.25')

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
print('Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression')

# values
# x sh lat
# y - south hem wind speed
y_sh_wind = s_hemisphere_data['wind speed']

# regress values
sh_ws_slope, sh_ws_int, sh_ws_r, sh_ws_p, sh_ws_stderr = linregress(x_sh_lat, y_sh_wind)
# fit
sh_ws_fit = sh_ws_slope * x_sh_lat + sh_ws_int

# equation
sh_ws_eq = f'y = {round(sh_ws_slope,2)}x + {round(sh_ws_int,2)}'
print(f'Linear Regression Equation: {sh_ws_eq}')

# correlation
sh_ws_corr = st.pearsonr(x_sh_lat, y_sh_wind)
print(f'Correlation: {sh_ws_corr[0]}')

# plotting
# scatter
plt.scatter(x_sh_lat, y_sh_wind, marker='o', facecolors='lightsteelblue', edgecolors='black', s=50, alpha=0.75)
plt.grid()
plt.title('Southern Hemisphere - Wind Speed (mph) vs. Latitude')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')

# regress line
plt.plot(x_sh_lat, sh_ws_fit, 'k--')
plt.annotate(sh_ws_eq, (-55, 15))
# Out:
# Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
# Linear Regression Equation: y = -0.07x + 6.87
# Correlation: -0.16071466096483658
# Text(-55, 15, 'y = -0.07x + 6.87')

# %%
# Data Analysis

# 1 - Max temperature is higher the closer the city is to the equator

# 2 - The Northern Hemisphere has higher humidity than the southern hemisphere

# 3 - Wind Speeds are lower in the souther hemisphere
