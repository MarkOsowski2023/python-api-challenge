# %% [markdown]
# # WeatherPy
# ----

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import json
from pprint import pprint
# Import API key
from config import weather_api_key
import scipy.stats as st

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 618

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Using OpenWeatherMap Direct Geocoding API
# Using For Loop to loop through cities
# Using a try/except block to determine which cities are found and not found
# storing the cities that are found in a list
# creating a dataframe with the information from the cities that are found
# print(cities)
# api call
# http://api.openweathermap.org/geo/1.0/direct?q={city}&limit={limit}&appid={API key}
url = 'http://api.openweathermap.org/geo/1.0/direct?q='
limit = 1
api_key = weather_api_key

weather_dict = {
    'city': cities,
    'lat': "",
    'lng': "",
}
weather_df = pd.DataFrame(weather_dict)
weather_df.head()

for city in cities:
    query_url = f'{url}{city}&limit={limit}&appid={api_key}'
    response = requests.get(query_url).json()
#     pprint(response)
    try:
        weather_df.loc[weather_df['city'] == city, 'lat'] = response[0]['lat']
        weather_df.loc[weather_df['city'] == city, 'lng'] = response[0]['lon']
        print(f'{city} found: processing data')
    except:
        print('City not found')
        pass
# Out:
# dhaka found: processing data
# kodiak found: processing data
# dikson found: processing data
# luwuk found: processing data
# port alfred found: processing data
# ushuaia found: processing data
# albany found: processing data
# rikitea found: processing data
# vaitupu found: processing data
# mahebourg found: processing data
# magrath found: processing data
# lodja found: processing data
# arraial do cabo found: processing data
# rivera found: processing data
# luanda found: processing data
# punta arenas found: processing data
# carnarvon found: processing data
# puerto ayora found: processing data
# caravelas found: processing data
# nanortalik found: processing data
# tambura found: processing data
# vaini found: processing data
# leningradskiy found: processing data
# asau found: processing data
# hobart found: processing data
# butaritari found: processing data
# roald found: processing data
# barrow found: processing data
# nikolskoye found: processing data
# mount isa found: processing data
# severo-kurilsk found: processing data
# myitkyina found: processing data
# kalmunai found: processing data
# antofagasta found: processing data
# bengkulu found: processing data
# bonthe found: processing data
# am timan found: processing data
# kahului found: processing data
# mangrol found: processing data
# bilma found: processing data
# rapar found: processing data
# saint-philippe found: processing data
# mataura found: processing data
# bonavista found: processing data
# bubaque found: processing data
# bluff found: processing data
# kapaa found: processing data
# yellowknife found: processing data
# gravdal found: processing data
# ahipara found: processing data
# halalo found: processing data
# jamestown found: processing data
# reconquista found: processing data
# cape town found: processing data
# norman wells found: processing data
# chokurdakh found: processing data
# amderma found: processing data
# thompson found: processing data
# rio gallegos found: processing data
# kaka found: processing data
# hithadhoo found: processing data
# kodino found: processing data
# chuy found: processing data
# illoqqortoormiut found: processing data
# saint-augustin found: processing data
# victoria found: processing data
# ancud found: processing data
# barentsburg found: processing data
# puerto escondido found: processing data
# akyab found: processing data
# chimbote found: processing data
# mar del plata found: processing data
# besikduzu found: processing data
# rundu found: processing data
# deputatskiy found: processing data
# georgetown found: processing data
# iqaluit found: processing data
# gorontalo found: processing data
# tautira found: processing data
# busselton found: processing data
# pacific grove found: processing data
# umm durman found: processing data
# bethel found: processing data
# little current found: processing data
# penzance found: processing data
# coari found: processing data
# City not found
# kidal found: processing data
# flinders found: processing data
# ponta do sol found: processing data
# pirganj found: processing data
# awbari found: processing data
# north bend found: processing data
# katsuura found: processing data
# City not found
# rocha found: processing data
# ruatoria found: processing data
# avarua found: processing data
# gigmoto found: processing data
# alamor found: processing data
# vestmannaeyjar found: processing data
# pafos found: processing data
# atuona found: processing data
# kuragino found: processing data
# labuhan found: processing data
# adre found: processing data
# saldanha found: processing data
# lebu found: processing data
# moberly found: processing data
# meulaboh found: processing data
# comodoro rivadavia found: processing data
# samusu found: processing data
# cabo san lucas found: processing data
# palabuhanratu found: processing data
# pisco found: processing data
# upernavik found: processing data
# tanout found: processing data
# karratha found: processing data
# syamzha found: processing data
# hofn found: processing data
# ayios matthaios found: processing data
# zaraza found: processing data
# benicarlo found: processing data
# grand gaube found: processing data
# tiksi found: processing data
# sao gabriel da cachoeira found: processing data
# taoudenni found: processing data
# troitskoye found: processing data
# saint-pierre found: processing data
# ribeira grande found: processing data
# belmonte found: processing data
# muros found: processing data
# golfito found: processing data
# bafq found: processing data
# fort nelson found: processing data
# kavieng found: processing data
# sandane found: processing data
# ambovombe found: processing data
# ilulissat found: processing data
# jalu found: processing data
# kirakira found: processing data
# egvekinot found: processing data
# almaznyy found: processing data
# grand river south east found: processing data
# lorengau found: processing data
# isangel found: processing data
# port hueneme found: processing data
# babu found: processing data
# cayenne found: processing data
# vila franca do campo found: processing data
# nogent-le-rotrou found: processing data
# manokwari found: processing data
# port elizabeth found: processing data
# torbay found: processing data
# qaanaaq found: processing data
# shache found: processing data
# zihuatanejo found: processing data
# portland found: processing data
# portobelo found: processing data
# hilo found: processing data
# tubruq found: processing data
# dabola found: processing data
# sault sainte marie found: processing data
# cascais found: processing data
# airai found: processing data
# sao joao da barra found: processing data
# seydi found: processing data
# vasteras found: processing data
# la crosse found: processing data
# oktyabrskiy found: processing data
# mosquera found: processing data
# zeya found: processing data
# puerto lopez found: processing data
# faanui found: processing data
# longyearbyen found: processing data
# perpignan found: processing data
# bonfim found: processing data
# stornoway found: processing data
# katobu found: processing data
# tarko-sale found: processing data
# shelburne found: processing data
# uwayl found: processing data
# kruisfontein found: processing data
# boende found: processing data
# sorland found: processing data
# wajima found: processing data
# nogliki found: processing data
# jacmel found: processing data
# City not found
# twentynine palms found: processing data
# lompoc found: processing data
# guerrero negro found: processing data
# City not found
# cidreira found: processing data
# hasaki found: processing data
# tsihombe found: processing data
# grojec found: processing data
# bhatkal found: processing data
# dakar found: processing data
# constitucion found: processing data
# imeni poliny osipenko found: processing data
# narsaq found: processing data
# todos santos found: processing data
# karaul found: processing data
# henties bay found: processing data
# viedma found: processing data
# port hardy found: processing data
# scarborough found: processing data
# te anau found: processing data
# saskylakh found: processing data
# findlay found: processing data
# fougamou found: processing data
# kaitangata found: processing data
# bredasdorp found: processing data
# sale found: processing data
# dongsheng found: processing data
# ust-maya found: processing data
# savannah bight found: processing data
# tasiilaq found: processing data
# yasnyy found: processing data
# umm kaddadah found: processing data
# kati found: processing data
# rawannawi found: processing data
# ipua found: processing data
# guaymas found: processing data
# amapa found: processing data
# vao found: processing data
# souillac found: processing data
# calvinia found: processing data
# geraldton found: processing data
# morristown found: processing data
# batagay-alyta found: processing data
# hermanus found: processing data
# grand centre found: processing data
# mount gambier found: processing data
# sitka found: processing data
# dolinsk found: processing data
# camacupa found: processing data
# mys shmidta found: processing data
# mao found: processing data
# great yarmouth found: processing data
# gulshat found: processing data
# tupik found: processing data
# belokurikha found: processing data
# tevaitoa found: processing data
# provideniya found: processing data
# fevralsk found: processing data
# City not found
# new norfolk found: processing data
# belushya guba found: processing data
# copiapo found: processing data
# moose factory found: processing data
# castro found: processing data
# attawapiskat found: processing data
# raga found: processing data
# dawlatabad found: processing data
# alekseyevsk found: processing data
# ponta delgada found: processing data
# fonte boa found: processing data
# olga found: processing data
# mujiayingzi found: processing data
# east london found: processing data
# vilani found: processing data
# berlevag found: processing data
# vikulovo found: processing data
# whitehorse found: processing data
# saint-joseph found: processing data
# maniitsoq found: processing data
# ostrovnoy found: processing data
# trofors found: processing data
# illapel found: processing data
# City not found
# aneho found: processing data
# tomatlan found: processing data
# truth or consequences found: processing data
# saint anthony found: processing data
# turochak found: processing data
# smidovich found: processing data
# port macquarie found: processing data
# pinehurst found: processing data
# gijon found: processing data
# lerwick found: processing data
# kamenskoye found: processing data
# pevek found: processing data
# korla found: processing data
# kalengwa found: processing data
# sao filipe found: processing data
# astoria found: processing data
# vilhena found: processing data
# axim found: processing data
# terrace found: processing data
# talesh found: processing data
# lakatoro found: processing data
# natchitoches found: processing data
# brightwater found: processing data
# goderich found: processing data
# buala found: processing data
# kununurra found: processing data
# haines junction found: processing data
# mut found: processing data
# khorramshahr found: processing data
# talnakh found: processing data
# balsas found: processing data
# guangyuan found: processing data
# vila velha found: processing data
# fairbanks found: processing data
# ecoporanga found: processing data
# zhangjiakou found: processing data
# rawson found: processing data
# linxia found: processing data
# tynda found: processing data
# tuggurt found: processing data
# chulman found: processing data
# zhezkazgan found: processing data
# manzanillo found: processing data
# evensk found: processing data
# leshukonskoye found: processing data
# khandyga found: processing data
# auki found: processing data
# buritizeiro found: processing data
# college found: processing data
# saint-francois found: processing data
# jibuti found: processing data
# hovd found: processing data
# garden acres found: processing data
# aitape found: processing data
# iguatemi found: processing data
# zhigansk found: processing data
# dingle found: processing data
# tuatapere found: processing data
# santo tomas found: processing data
# gweta found: processing data
# clovis found: processing data
# port-gentil found: processing data
# paita found: processing data
# camden found: processing data
# itarema found: processing data
# City not found
# aruja found: processing data
# itapirapua found: processing data
# atasu found: processing data
# naze found: processing data
# bambous virieux found: processing data
# klaksvik found: processing data
# tuktoyaktuk found: processing data
# kleck found: processing data
# kalaleh found: processing data
# asadabad found: processing data
# alofi found: processing data
# solwezi found: processing data
# moba found: processing data
# broome found: processing data
# lexington found: processing data
# san cristobal found: processing data
# hami found: processing data
# barahona found: processing data
# City not found
# umzimvubu found: processing data
# lasa found: processing data
# port blair found: processing data
# lavrentiya found: processing data
# tabou found: processing data
# sovetskiy found: processing data
# peace river found: processing data
# City not found
# harrison found: processing data
# zhangye found: processing data
# sampit found: processing data
# nizhneyansk found: processing data
# sakakah found: processing data
# surgut found: processing data
# nizwa found: processing data
# bathsheba found: processing data
# kloulklubed found: processing data
# kargasok found: processing data
# kulhudhuffushi found: processing data
# lagoa found: processing data
# orange found: processing data
# borogontsy found: processing data
# ushtobe found: processing data
# vardo found: processing data
# grindavik found: processing data
# harper found: processing data
# hokitika found: processing data
# punta alta found: processing data
# khuldabad found: processing data
# saint george found: processing data
# gao found: processing data
# manzhouli found: processing data
# goksun found: processing data
# leh found: processing data
# sandwick found: processing data
# acapulco found: processing data
# vangaindrano found: processing data
# san antonio found: processing data
# lensk found: processing data
# verkhnyaya khava found: processing data
# paamiut found: processing data
# coos bay found: processing data
# yuxia found: processing data
# broken hill found: processing data
# villanueva found: processing data
# champerico found: processing data
# teahupoo found: processing data
# clyde river found: processing data
# coro found: processing data
# necochea found: processing data
# buchanan found: processing data
# dong hoi found: processing data
# komsomolskiy found: processing data
# santa maria found: processing data
# capoeiras found: processing data
# barcelona found: processing data
# saint-gaudens found: processing data
# olafsvik found: processing data
# bollnas found: processing data
# daule found: processing data
# erzincan found: processing data
# lazaro cardenas found: processing data
# monrovia found: processing data
# nyzhni sirohozy found: processing data
# tramore found: processing data
# solnechnyy found: processing data
# City not found
# toila found: processing data
# City not found
# pathein found: processing data
# abiy adi found: processing data
# fort frances found: processing data
# teguldet found: processing data
# srednekolymsk found: processing data
# radstadt found: processing data
# half moon bay found: processing data
# mackay found: processing data
# marcona found: processing data
# richards bay found: processing data
# shingu found: processing data
# svetlaya found: processing data
# bundaberg found: processing data
# naryan-mar found: processing data
# sao felix do xingu found: processing data
# mitu found: processing data
# domoni found: processing data
# qandahar found: processing data
# matay found: processing data
# kifri found: processing data
# berdigestyakh found: processing data
# agirish found: processing data
# santa rosa found: processing data
# vostok found: processing data
# vuktyl found: processing data
# verkhnevilyuysk found: processing data
# kimbe found: processing data
# anastasiyevskaya found: processing data
# nouadhibou found: processing data
# cabedelo found: processing data
# sar-e pul found: processing data
# san patricio found: processing data
# mwinilunga found: processing data
# carbondale found: processing data
# mandvi found: processing data
# City not found
# aklavik found: processing data
# safford found: processing data
# dosso found: processing data
# sola found: processing data
# muli found: processing data
# ballina found: processing data
# okahandja found: processing data
# taltal found: processing data
# juneau found: processing data
# City not found
# morondava found: processing data
# thinadhoo found: processing data
# vanimo found: processing data
# salinas found: processing data
# voh found: processing data
# katangli found: processing data
# xuddur found: processing data
# nosy varika found: processing data
# margate found: processing data
# kieta found: processing data
# esperance found: processing data
# finschhafen found: processing data
# erenhot found: processing data
# hegang found: processing data
# esil found: processing data
# dunedin found: processing data
# dajal found: processing data
# pangai found: processing data
# faya found: processing data
# san rafael found: processing data
# sisophon found: processing data
# miri found: processing data
# City not found
# avallon found: processing data
# kishanganj found: processing data
# ritchie found: processing data
# glace bay found: processing data
# barabai found: processing data
# hinton found: processing data
# tooele found: processing data
# linqiong found: processing data
# daru found: processing data
# lata found: processing data
# chukhloma found: processing data
# illela found: processing data
# kathu found: processing data
# seydisehir found: processing data
# kostinbrod found: processing data
# sept-iles found: processing data
# alta floresta found: processing data
# manado found: processing data
# vinces found: processing data
# ayame found: processing data
# zaozerne found: processing data
# northam found: processing data
# altay found: processing data
# wewak found: processing data
# mandan found: processing data
# sobolevo found: processing data
# paciran found: processing data
# embonas found: processing data
# sataua found: processing data
# turukhansk found: processing data
# soc trang found: processing data
# high level found: processing data
# hobyo found: processing data
# pukhrayan found: processing data
# changli found: processing data
# kuusamo found: processing data
# yurga found: processing data
# melekhovskaya found: processing data
# goteborg found: processing data
# cap malheureux found: processing data
# manicore found: processing data
# balkanabat found: processing data
# kamenka found: processing data
# adrar found: processing data
# shimoda found: processing data
# ulladulla found: processing data
# kalat found: processing data
# City not found
# fortuna found: processing data
# hastings found: processing data
# bud found: processing data
# cumaribo found: processing data
# lodingen found: processing data
# kingman found: processing data
# sile found: processing data
# City not found
# nuoro found: processing data
# myrtle beach found: processing data
# atar found: processing data
# acatlan found: processing data
# westport found: processing data
# City not found
# mukhen found: processing data
# boa vista found: processing data
# benjamin constant found: processing data
# suamico found: processing data
# newton abbot found: processing data
# City not found
# waitara found: processing data
# City not found
# khatanga found: processing data
# ewa beach found: processing data
# el alto found: processing data
# longkou found: processing data
# brasilia found: processing data
# halifax found: processing data
# luganville found: processing data
# huarmey found: processing data
# City not found
# kinel found: processing data
# ambilobe found: processing data
# ust-kuyga found: processing data
# pingxiang found: processing data
# amahai found: processing data
# bac lieu found: processing data
# atbasar found: processing data
# amga found: processing data
# businga found: processing data
# erzin found: processing data
# san andres found: processing data
# City not found
# truro found: processing data
# hamilton found: processing data
# ternate found: processing data
# el faiyum found: processing data
# gagino found: processing data
# iralaya found: processing data
# City not found
# artyk found: processing data
# quatis found: processing data
# den helder found: processing data
# martapura found: processing data
# kupang found: processing data
# husavik found: processing data
# utiroa found: processing data
# burnie found: processing data
# City not found
# luhyny found: processing data
# louisbourg found: processing data
# yumen found: processing data
# kropotkin found: processing data
# tefe found: processing data
# guanhaes found: processing data
# sompeta found: processing data
# velen found: processing data
# port hedland found: processing data
# svetlogorsk found: processing data
# dudinka found: processing data
# kolondieba found: processing data
# City not found
# City not found
# labuan found: processing data
# rahimatpur found: processing data

# %%
weather_df.head()
# Out:
#           city       lat      lng
# 0        dhaka   23.7862  90.4026
# 1       kodiak     57.79 -152.407
# 2       dikson   73.5084  80.5124
# 3        luwuk -0.952823  122.788
# 4  port alfred  -33.5982  26.8915

# %%
weather_df['max temperature'] = ""
weather_df['humidity'] = ""
weather_df['cloudiness'] = ""
weather_df['wind speed'] = ""
weather_df['country'] = ""
weather_df['date'] = ""
weather_df.head()
# Out:
#           city       lat      lng max temperature humidity cloudiness  \
# 0        dhaka   23.7862  90.4026
# 1       kodiak     57.79 -152.407
# 2       dikson   73.5084  80.5124
# 3        luwuk -0.952823  122.788
# 4  port alfred  -33.5982  26.8915
#
#   wind speed country date
# 0
# 1
# 2
# 3
# 4

# %%
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid={API key}&units=imperial
units = 'imperial'
weather_url = 'https://api.openweathermap.org/data/2.5/weather?lat='

for city in cities:
    lat = weather_df.loc[weather_df['city'] == city, 'lat'].values[0]
    lon = weather_df.loc[weather_df['city'] == city, 'lng'].values[0]
    weather_query = f'{weather_url}{lat}&lon={lon}&appid={api_key}&units={units}'
    weather_response = requests.get(weather_query).json()
    
    try:
        weather_df.loc[weather_df['city'] == city, 'max temperature'] = weather_response['main']['temp_max']
        weather_df.loc[weather_df['city'] == city, 'humidity'] = weather_response['main']['humidity']
        weather_df.loc[weather_df['city'] == city, 'cloudiness'] = weather_response['clouds']['all']
        weather_df.loc[weather_df['city'] == city, 'wind speed'] = weather_response['wind']['speed']
        weather_df.loc[weather_df['city'] == city, 'country'] = weather_response['sys']['country']
        weather_df.loc[weather_df['city'] == city, 'date'] = weather_response['dt']
        print(f'Processing Weather Data For: {city}')
    except:
        print('No Data Reported')
        pass
# Out:
# Processing Weather Data For: dhaka
# Processing Weather Data For: kodiak
# Processing Weather Data For: dikson
# Processing Weather Data For: luwuk
# Processing Weather Data For: port alfred
# Processing Weather Data For: ushuaia
# Processing Weather Data For: albany
# Processing Weather Data For: rikitea
# Processing Weather Data For: vaitupu
# Processing Weather Data For: mahebourg
# Processing Weather Data For: magrath
# Processing Weather Data For: lodja
# Processing Weather Data For: arraial do cabo
# Processing Weather Data For: rivera
# Processing Weather Data For: luanda
# Processing Weather Data For: punta arenas
# Processing Weather Data For: carnarvon
# Processing Weather Data For: puerto ayora
# Processing Weather Data For: caravelas
# Processing Weather Data For: nanortalik
# Processing Weather Data For: tambura
# Processing Weather Data For: vaini
# Processing Weather Data For: leningradskiy
# Processing Weather Data For: asau
# Processing Weather Data For: hobart
# Processing Weather Data For: butaritari
# Processing Weather Data For: roald
# Processing Weather Data For: barrow
# Processing Weather Data For: nikolskoye
# Processing Weather Data For: mount isa
# Processing Weather Data For: severo-kurilsk
# Processing Weather Data For: myitkyina
# Processing Weather Data For: kalmunai
# Processing Weather Data For: antofagasta
# Processing Weather Data For: bengkulu
# Processing Weather Data For: bonthe
# Processing Weather Data For: am timan
# Processing Weather Data For: kahului
# Processing Weather Data For: mangrol
# Processing Weather Data For: bilma
# Processing Weather Data For: rapar
# Processing Weather Data For: saint-philippe
# Processing Weather Data For: mataura
# Processing Weather Data For: bonavista
# Processing Weather Data For: bubaque
# Processing Weather Data For: bluff
# Processing Weather Data For: kapaa
# Processing Weather Data For: yellowknife
# Processing Weather Data For: gravdal
# Processing Weather Data For: ahipara
# Processing Weather Data For: halalo
# Processing Weather Data For: jamestown
# Processing Weather Data For: reconquista
# Processing Weather Data For: cape town
# Processing Weather Data For: norman wells
# Processing Weather Data For: chokurdakh
# Processing Weather Data For: amderma
# Processing Weather Data For: thompson
# Processing Weather Data For: rio gallegos
# Processing Weather Data For: kaka
# Processing Weather Data For: hithadhoo
# Processing Weather Data For: kodino
# Processing Weather Data For: chuy
# Processing Weather Data For: illoqqortoormiut
# Processing Weather Data For: saint-augustin
# Processing Weather Data For: victoria
# Processing Weather Data For: ancud
# Processing Weather Data For: barentsburg
# Processing Weather Data For: puerto escondido
# Processing Weather Data For: akyab
# Processing Weather Data For: chimbote
# Processing Weather Data For: mar del plata
# Processing Weather Data For: besikduzu
# Processing Weather Data For: rundu
# Processing Weather Data For: deputatskiy
# Processing Weather Data For: georgetown
# Processing Weather Data For: iqaluit
# Processing Weather Data For: gorontalo
# Processing Weather Data For: tautira
# Processing Weather Data For: busselton
# Processing Weather Data For: pacific grove
# Processing Weather Data For: umm durman
# Processing Weather Data For: bethel
# Processing Weather Data For: little current
# Processing Weather Data For: penzance
# Processing Weather Data For: coari
# No Data Reported
# Processing Weather Data For: kidal
# Processing Weather Data For: flinders
# Processing Weather Data For: ponta do sol
# Processing Weather Data For: pirganj
# Processing Weather Data For: awbari
# Processing Weather Data For: north bend
# Processing Weather Data For: katsuura
# No Data Reported
# Processing Weather Data For: rocha
# Processing Weather Data For: ruatoria
# Processing Weather Data For: avarua
# Processing Weather Data For: gigmoto
# Processing Weather Data For: alamor
# Processing Weather Data For: vestmannaeyjar
# Processing Weather Data For: pafos
# Processing Weather Data For: atuona
# Processing Weather Data For: kuragino
# Processing Weather Data For: labuhan
# Processing Weather Data For: adre
# Processing Weather Data For: saldanha
# Processing Weather Data For: lebu
# Processing Weather Data For: moberly
# Processing Weather Data For: meulaboh
# Processing Weather Data For: comodoro rivadavia
# Processing Weather Data For: samusu
# Processing Weather Data For: cabo san lucas
# Processing Weather Data For: palabuhanratu
# Processing Weather Data For: pisco
# Processing Weather Data For: upernavik
# Processing Weather Data For: tanout
# Processing Weather Data For: karratha
# Processing Weather Data For: syamzha
# Processing Weather Data For: hofn
# Processing Weather Data For: ayios matthaios
# Processing Weather Data For: zaraza
# Processing Weather Data For: benicarlo
# Processing Weather Data For: grand gaube
# Processing Weather Data For: tiksi
# Processing Weather Data For: sao gabriel da cachoeira
# Processing Weather Data For: taoudenni
# Processing Weather Data For: troitskoye
# Processing Weather Data For: saint-pierre
# Processing Weather Data For: ribeira grande
# Processing Weather Data For: belmonte
# Processing Weather Data For: muros
# Processing Weather Data For: golfito
# Processing Weather Data For: bafq
# Processing Weather Data For: fort nelson
# Processing Weather Data For: kavieng
# Processing Weather Data For: sandane
# Processing Weather Data For: ambovombe
# Processing Weather Data For: ilulissat
# Processing Weather Data For: jalu
# Processing Weather Data For: kirakira
# Processing Weather Data For: egvekinot
# Processing Weather Data For: almaznyy
# Processing Weather Data For: grand river south east
# Processing Weather Data For: lorengau
# Processing Weather Data For: isangel
# Processing Weather Data For: port hueneme
# Processing Weather Data For: babu
# Processing Weather Data For: cayenne
# Processing Weather Data For: vila franca do campo
# Processing Weather Data For: nogent-le-rotrou
# Processing Weather Data For: manokwari
# Processing Weather Data For: port elizabeth
# Processing Weather Data For: torbay
# Processing Weather Data For: qaanaaq
# Processing Weather Data For: shache
# Processing Weather Data For: zihuatanejo
# Processing Weather Data For: portland
# Processing Weather Data For: portobelo
# Processing Weather Data For: hilo
# Processing Weather Data For: tubruq
# Processing Weather Data For: dabola
# Processing Weather Data For: sault sainte marie
# Processing Weather Data For: cascais
# Processing Weather Data For: airai
# Processing Weather Data For: sao joao da barra
# Processing Weather Data For: seydi
# Processing Weather Data For: vasteras
# Processing Weather Data For: la crosse
# Processing Weather Data For: oktyabrskiy
# Processing Weather Data For: mosquera
# Processing Weather Data For: zeya
# Processing Weather Data For: puerto lopez
# Processing Weather Data For: faanui
# Processing Weather Data For: longyearbyen
# Processing Weather Data For: perpignan
# Processing Weather Data For: bonfim
# Processing Weather Data For: stornoway
# Processing Weather Data For: katobu
# Processing Weather Data For: tarko-sale
# Processing Weather Data For: shelburne
# Processing Weather Data For: uwayl
# Processing Weather Data For: kruisfontein
# Processing Weather Data For: boende
# Processing Weather Data For: sorland
# Processing Weather Data For: wajima
# Processing Weather Data For: nogliki
# Processing Weather Data For: jacmel
# No Data Reported
# Processing Weather Data For: twentynine palms
# Processing Weather Data For: lompoc
# Processing Weather Data For: guerrero negro
# No Data Reported
# Processing Weather Data For: cidreira
# Processing Weather Data For: hasaki
# Processing Weather Data For: tsihombe
# Processing Weather Data For: grojec
# Processing Weather Data For: bhatkal
# Processing Weather Data For: dakar
# Processing Weather Data For: constitucion
# Processing Weather Data For: imeni poliny osipenko
# Processing Weather Data For: narsaq
# Processing Weather Data For: todos santos
# Processing Weather Data For: karaul
# Processing Weather Data For: henties bay
# Processing Weather Data For: viedma
# Processing Weather Data For: port hardy
# Processing Weather Data For: scarborough
# Processing Weather Data For: te anau
# Processing Weather Data For: saskylakh
# Processing Weather Data For: findlay
# Processing Weather Data For: fougamou
# Processing Weather Data For: kaitangata
# Processing Weather Data For: bredasdorp
# Processing Weather Data For: sale
# Processing Weather Data For: dongsheng
# Processing Weather Data For: ust-maya
# Processing Weather Data For: savannah bight
# Processing Weather Data For: tasiilaq
# Processing Weather Data For: yasnyy
# Processing Weather Data For: umm kaddadah
# Processing Weather Data For: kati
# Processing Weather Data For: rawannawi
# Processing Weather Data For: ipua
# Processing Weather Data For: guaymas
# Processing Weather Data For: amapa
# Processing Weather Data For: vao
# Processing Weather Data For: souillac
# Processing Weather Data For: calvinia
# Processing Weather Data For: geraldton
# Processing Weather Data For: morristown
# Processing Weather Data For: batagay-alyta
# Processing Weather Data For: hermanus
# Processing Weather Data For: grand centre
# Processing Weather Data For: mount gambier
# Processing Weather Data For: sitka
# Processing Weather Data For: dolinsk
# Processing Weather Data For: camacupa
# Processing Weather Data For: mys shmidta
# Processing Weather Data For: mao
# Processing Weather Data For: great yarmouth
# Processing Weather Data For: gulshat
# Processing Weather Data For: tupik
# Processing Weather Data For: belokurikha
# Processing Weather Data For: tevaitoa
# Processing Weather Data For: provideniya
# Processing Weather Data For: fevralsk
# No Data Reported
# Processing Weather Data For: new norfolk
# No Data Reported
# Processing Weather Data For: copiapo
# Processing Weather Data For: moose factory
# Processing Weather Data For: castro
# Processing Weather Data For: attawapiskat
# Processing Weather Data For: raga
# Processing Weather Data For: dawlatabad
# Processing Weather Data For: alekseyevsk
# Processing Weather Data For: ponta delgada
# Processing Weather Data For: fonte boa
# Processing Weather Data For: olga
# Processing Weather Data For: mujiayingzi
# Processing Weather Data For: east london
# Processing Weather Data For: vilani
# Processing Weather Data For: berlevag
# Processing Weather Data For: vikulovo
# Processing Weather Data For: whitehorse
# Processing Weather Data For: saint-joseph
# Processing Weather Data For: maniitsoq
# Processing Weather Data For: ostrovnoy
# Processing Weather Data For: trofors
# Processing Weather Data For: illapel
# No Data Reported
# Processing Weather Data For: aneho
# Processing Weather Data For: tomatlan
# Processing Weather Data For: truth or consequences
# Processing Weather Data For: saint anthony
# Processing Weather Data For: turochak
# Processing Weather Data For: smidovich
# Processing Weather Data For: port macquarie
# Processing Weather Data For: pinehurst
# Processing Weather Data For: gijon
# Processing Weather Data For: lerwick
# Processing Weather Data For: kamenskoye
# Processing Weather Data For: pevek
# Processing Weather Data For: korla
# Processing Weather Data For: kalengwa
# Processing Weather Data For: sao filipe
# Processing Weather Data For: astoria
# Processing Weather Data For: vilhena
# Processing Weather Data For: axim
# Processing Weather Data For: terrace
# Processing Weather Data For: talesh
# Processing Weather Data For: lakatoro
# Processing Weather Data For: natchitoches
# Processing Weather Data For: brightwater
# Processing Weather Data For: goderich
# Processing Weather Data For: buala
# Processing Weather Data For: kununurra
# Processing Weather Data For: haines junction
# Processing Weather Data For: mut
# Processing Weather Data For: khorramshahr
# Processing Weather Data For: talnakh
# Processing Weather Data For: balsas
# Processing Weather Data For: guangyuan
# Processing Weather Data For: vila velha
# Processing Weather Data For: fairbanks
# Processing Weather Data For: ecoporanga
# Processing Weather Data For: zhangjiakou
# Processing Weather Data For: rawson
# Processing Weather Data For: linxia
# Processing Weather Data For: tynda
# Processing Weather Data For: tuggurt
# Processing Weather Data For: chulman
# Processing Weather Data For: zhezkazgan
# Processing Weather Data For: manzanillo
# Processing Weather Data For: evensk
# Processing Weather Data For: leshukonskoye
# Processing Weather Data For: khandyga
# Processing Weather Data For: auki
# Processing Weather Data For: buritizeiro
# Processing Weather Data For: college
# Processing Weather Data For: saint-francois
# Processing Weather Data For: jibuti
# Processing Weather Data For: hovd
# Processing Weather Data For: garden acres
# Processing Weather Data For: aitape
# Processing Weather Data For: iguatemi
# Processing Weather Data For: zhigansk
# Processing Weather Data For: dingle
# Processing Weather Data For: tuatapere
# Processing Weather Data For: santo tomas
# Processing Weather Data For: gweta
# Processing Weather Data For: clovis
# Processing Weather Data For: port-gentil
# Processing Weather Data For: paita
# Processing Weather Data For: camden
# Processing Weather Data For: itarema
# No Data Reported
# Processing Weather Data For: aruja
# Processing Weather Data For: itapirapua
# Processing Weather Data For: atasu
# Processing Weather Data For: naze
# Processing Weather Data For: bambous virieux
# Processing Weather Data For: klaksvik
# Processing Weather Data For: tuktoyaktuk
# Processing Weather Data For: kleck
# Processing Weather Data For: kalaleh
# Processing Weather Data For: asadabad
# Processing Weather Data For: alofi
# Processing Weather Data For: solwezi
# Processing Weather Data For: moba
# Processing Weather Data For: broome
# Processing Weather Data For: lexington
# Processing Weather Data For: san cristobal
# Processing Weather Data For: hami
# Processing Weather Data For: barahona
# No Data Reported
# Processing Weather Data For: umzimvubu
# Processing Weather Data For: lasa
# Processing Weather Data For: port blair
# Processing Weather Data For: lavrentiya
# Processing Weather Data For: tabou
# Processing Weather Data For: sovetskiy
# Processing Weather Data For: peace river
# No Data Reported
# Processing Weather Data For: harrison
# Processing Weather Data For: zhangye
# Processing Weather Data For: sampit
# Processing Weather Data For: nizhneyansk
# Processing Weather Data For: sakakah
# Processing Weather Data For: surgut
# Processing Weather Data For: nizwa
# Processing Weather Data For: bathsheba
# Processing Weather Data For: kloulklubed
# Processing Weather Data For: kargasok
# Processing Weather Data For: kulhudhuffushi
# Processing Weather Data For: lagoa
# Processing Weather Data For: orange
# Processing Weather Data For: borogontsy
# Processing Weather Data For: ushtobe
# Processing Weather Data For: vardo
# Processing Weather Data For: grindavik
# Processing Weather Data For: harper
# Processing Weather Data For: hokitika
# Processing Weather Data For: punta alta
# Processing Weather Data For: khuldabad
# Processing Weather Data For: saint george
# Processing Weather Data For: gao
# Processing Weather Data For: manzhouli
# Processing Weather Data For: goksun
# Processing Weather Data For: leh
# Processing Weather Data For: sandwick
# Processing Weather Data For: acapulco
# Processing Weather Data For: vangaindrano
# Processing Weather Data For: san antonio
# Processing Weather Data For: lensk
# Processing Weather Data For: verkhnyaya khava
# Processing Weather Data For: paamiut
# Processing Weather Data For: coos bay
# Processing Weather Data For: yuxia
# Processing Weather Data For: broken hill
# Processing Weather Data For: villanueva
# Processing Weather Data For: champerico
# Processing Weather Data For: teahupoo
# Processing Weather Data For: clyde river
# Processing Weather Data For: coro
# Processing Weather Data For: necochea
# Processing Weather Data For: buchanan
# Processing Weather Data For: dong hoi
# Processing Weather Data For: komsomolskiy
# Processing Weather Data For: santa maria
# Processing Weather Data For: capoeiras
# Processing Weather Data For: barcelona
# Processing Weather Data For: saint-gaudens
# Processing Weather Data For: olafsvik
# Processing Weather Data For: bollnas
# Processing Weather Data For: daule
# Processing Weather Data For: erzincan
# Processing Weather Data For: lazaro cardenas
# Processing Weather Data For: monrovia
# Processing Weather Data For: nyzhni sirohozy
# Processing Weather Data For: tramore
# Processing Weather Data For: solnechnyy
# No Data Reported
# Processing Weather Data For: toila
# No Data Reported
# Processing Weather Data For: pathein
# Processing Weather Data For: abiy adi
# Processing Weather Data For: fort frances
# Processing Weather Data For: teguldet
# Processing Weather Data For: srednekolymsk
# Processing Weather Data For: radstadt
# Processing Weather Data For: half moon bay
# Processing Weather Data For: mackay
# Processing Weather Data For: marcona
# Processing Weather Data For: richards bay
# Processing Weather Data For: shingu
# Processing Weather Data For: svetlaya
# Processing Weather Data For: bundaberg
# Processing Weather Data For: naryan-mar
# Processing Weather Data For: sao felix do xingu
# Processing Weather Data For: mitu
# Processing Weather Data For: domoni
# Processing Weather Data For: qandahar
# Processing Weather Data For: matay
# Processing Weather Data For: kifri
# Processing Weather Data For: berdigestyakh
# Processing Weather Data For: agirish
# Processing Weather Data For: santa rosa
# No Data Reported
# Processing Weather Data For: vuktyl
# Processing Weather Data For: verkhnevilyuysk
# Processing Weather Data For: kimbe
# Processing Weather Data For: anastasiyevskaya
# Processing Weather Data For: nouadhibou
# Processing Weather Data For: cabedelo
# Processing Weather Data For: sar-e pul
# Processing Weather Data For: san patricio
# Processing Weather Data For: mwinilunga
# Processing Weather Data For: carbondale
# Processing Weather Data For: mandvi
# No Data Reported
# Processing Weather Data For: aklavik
# Processing Weather Data For: safford
# Processing Weather Data For: dosso
# Processing Weather Data For: sola
# Processing Weather Data For: muli
# Processing Weather Data For: ballina
# Processing Weather Data For: okahandja
# Processing Weather Data For: taltal
# Processing Weather Data For: juneau
# No Data Reported
# Processing Weather Data For: morondava
# Processing Weather Data For: thinadhoo
# Processing Weather Data For: vanimo
# Processing Weather Data For: salinas
# Processing Weather Data For: voh
# Processing Weather Data For: katangli
# Processing Weather Data For: xuddur
# Processing Weather Data For: nosy varika
# Processing Weather Data For: margate
# Processing Weather Data For: kieta
# Processing Weather Data For: esperance
# Processing Weather Data For: finschhafen
# Processing Weather Data For: erenhot
# Processing Weather Data For: hegang
# Processing Weather Data For: esil
# Processing Weather Data For: dunedin
# Processing Weather Data For: dajal
# Processing Weather Data For: pangai
# Processing Weather Data For: faya
# Processing Weather Data For: san rafael
# Processing Weather Data For: sisophon
# Processing Weather Data For: miri
# No Data Reported
# Processing Weather Data For: avallon
# Processing Weather Data For: kishanganj
# Processing Weather Data For: ritchie
# Processing Weather Data For: glace bay
# Processing Weather Data For: barabai
# Processing Weather Data For: hinton
# Processing Weather Data For: tooele
# Processing Weather Data For: linqiong
# Processing Weather Data For: daru
# Processing Weather Data For: lata
# Processing Weather Data For: chukhloma
# Processing Weather Data For: illela
# Processing Weather Data For: kathu
# Processing Weather Data For: seydisehir
# Processing Weather Data For: kostinbrod
# Processing Weather Data For: sept-iles
# Processing Weather Data For: alta floresta
# Processing Weather Data For: manado
# Processing Weather Data For: vinces
# Processing Weather Data For: ayame
# Processing Weather Data For: zaozerne
# Processing Weather Data For: northam
# Processing Weather Data For: altay
# Processing Weather Data For: wewak
# Processing Weather Data For: mandan
# Processing Weather Data For: sobolevo
# Processing Weather Data For: paciran
# Processing Weather Data For: embonas
# Processing Weather Data For: sataua
# Processing Weather Data For: turukhansk
# Processing Weather Data For: soc trang
# Processing Weather Data For: high level
# Processing Weather Data For: hobyo
# Processing Weather Data For: pukhrayan
# Processing Weather Data For: changli
# Processing Weather Data For: kuusamo
# Processing Weather Data For: yurga
# Processing Weather Data For: melekhovskaya
# Processing Weather Data For: goteborg
# Processing Weather Data For: cap malheureux
# Processing Weather Data For: manicore
# Processing Weather Data For: balkanabat
# Processing Weather Data For: kamenka
# Processing Weather Data For: adrar
# Processing Weather Data For: shimoda
# Processing Weather Data For: ulladulla
# Processing Weather Data For: kalat
# No Data Reported
# Processing Weather Data For: fortuna
# Processing Weather Data For: hastings
# Processing Weather Data For: bud
# Processing Weather Data For: cumaribo
# Processing Weather Data For: lodingen
# Processing Weather Data For: kingman
# Processing Weather Data For: sile
# No Data Reported
# Processing Weather Data For: nuoro
# Processing Weather Data For: myrtle beach
# Processing Weather Data For: atar
# Processing Weather Data For: acatlan
# Processing Weather Data For: westport
# No Data Reported
# Processing Weather Data For: mukhen
# Processing Weather Data For: boa vista
# Processing Weather Data For: benjamin constant
# Processing Weather Data For: suamico
# Processing Weather Data For: newton abbot
# No Data Reported
# Processing Weather Data For: waitara
# No Data Reported
# Processing Weather Data For: khatanga
# Processing Weather Data For: ewa beach
# Processing Weather Data For: el alto
# Processing Weather Data For: longkou
# Processing Weather Data For: brasilia
# Processing Weather Data For: halifax
# Processing Weather Data For: luganville
# Processing Weather Data For: huarmey
# No Data Reported
# Processing Weather Data For: kinel
# Processing Weather Data For: ambilobe
# Processing Weather Data For: ust-kuyga
# Processing Weather Data For: pingxiang
# Processing Weather Data For: amahai
# Processing Weather Data For: bac lieu
# Processing Weather Data For: atbasar
# Processing Weather Data For: amga
# Processing Weather Data For: businga
# Processing Weather Data For: erzin
# Processing Weather Data For: san andres
# No Data Reported
# Processing Weather Data For: truro
# Processing Weather Data For: hamilton
# Processing Weather Data For: ternate
# Processing Weather Data For: el faiyum
# Processing Weather Data For: gagino
# Processing Weather Data For: iralaya
# No Data Reported
# Processing Weather Data For: artyk
# Processing Weather Data For: quatis
# Processing Weather Data For: den helder
# Processing Weather Data For: martapura
# Processing Weather Data For: kupang
# Processing Weather Data For: husavik
# Processing Weather Data For: utiroa
# Processing Weather Data For: burnie
# No Data Reported
# Processing Weather Data For: luhyny
# Processing Weather Data For: louisbourg
# Processing Weather Data For: yumen
# Processing Weather Data For: kropotkin
# Processing Weather Data For: tefe
# Processing Weather Data For: guanhaes
# Processing Weather Data For: sompeta
# Processing Weather Data For: velen
# Processing Weather Data For: port hedland
# Processing Weather Data For: svetlogorsk
# Processing Weather Data For: dudinka
# Processing Weather Data For: kolondieba
# No Data Reported
# No Data Reported
# Processing Weather Data For: labuan
# Processing Weather Data For: rahimatpur

# %%
# Cleaning the dataframe
# check counts()
weather_df.head()
print(weather_df.count())
print('-----------------------------------')
# drop all row with missing weather data
# replace rows "" -empty spaces with nan
# dropna
weather_df.replace("", np.nan, inplace=True)
clean_df = weather_df.dropna(how='any')
print(clean_df.count())
# Out:
# city               618
# lat                618
# lng                618
# max temperature    618
# humidity           618
# cloudiness         618
# wind speed         618
# country            618
# date               618
# dtype: int64
# -----------------------------------
# city               591
# lat                591
# lng                591
# max temperature    591
# humidity           591
# cloudiness         591
# wind speed         591
# country            591
# date               591
# dtype: int64

# %%
# Droping the extra temperature series that is still there from earlier, keeping max temperatuure series
# clean_df.drop('temperature', axis=1, inplace=True)
clean_df.head()
# Out:
#           city        lat         lng  max temperature  humidity  cloudiness  \
# 0        dhaka  23.786198   90.402615            82.38      78.0        40.0
# 1       kodiak  57.790000 -152.407222            56.71      88.0       100.0
# 2       dikson  73.508389   80.512382            40.98      96.0       100.0
# 3        luwuk  -0.952823  122.788020            75.42      94.0        99.0
# 4  port alfred -33.598184   26.891477            59.22      79.0        15.0
#
#    wind speed country          date
# 0        4.61      BD  1.659133e+09
# 1       10.36      US  1.659133e+09
# 2       16.42      RU  1.659133e+09
# 3        3.98      ID  1.659133e+09
# 4       12.71      ZA  1.659133e+09

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# dataframe to csv
clean_df.to_csv(output_data_file, encoding='utf-8', index=False)

# %%
clean_df
# Out:
#             city        lat         lng  max temperature  humidity  \
# 0          dhaka  23.786198   90.402615            82.38      78.0
# 1         kodiak  57.790000 -152.407222            56.71      88.0
# 2         dikson  73.508389   80.512382            40.98      96.0
# 3          luwuk  -0.952823  122.788020            75.42      94.0
# 4    port alfred -33.598184   26.891477            59.22      79.0
# ..           ...        ...         ...              ...       ...
# 611  svetlogorsk  54.941755   20.155086            59.52      67.0
# 612      dudinka  69.406067   86.175072            61.66      78.0
# 613   kolondieba  11.088520   -6.893416            73.33      89.0
# 616       labuan   5.276988  115.243356            80.96      89.0
# 617   rahimatpur  17.591297   74.198020            76.93      81.0
#
#      cloudiness  wind speed country          date
# 0          40.0        4.61      BD  1.659133e+09
# 1         100.0       10.36      US  1.659133e+09
# 2         100.0       16.42      RU  1.659133e+09
# 3          99.0        3.98      ID  1.659133e+09
# 4          15.0       12.71      ZA  1.659133e+09
# ..          ...         ...     ...           ...
# 611        70.0        9.80      RU  1.659134e+09
# 612        17.0        5.93      RU  1.659134e+09
# 613       100.0        4.47      ML  1.659134e+09
# 616        40.0        1.14      MY  1.659134e+09
# 617        94.0        3.44      IN  1.659134e+09
#
# [591 rows x 9 columns]

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
# .loc[] humidity > 100
print(clean_df.loc[clean_df['humidity'] > 100].head())
# Out:
# Empty DataFrame
# Columns: [city, lat, lng, max temperature, humidity, cloudiness, wind speed, country, date]
# Index: []

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# NEED TO COME BACK TO/ TO ADD DATE TO TITLE
# using plt.scatter
# x and y axis
x_lat = clean_df['lat']
max_temp = clean_df['max temperature']

plt.scatter(x_lat, max_temp, marker='o', facecolors='Red', edgecolors='black', s=50, alpha=0.85)
plt.grid()
plt.title(f'Max Temperature vs. Latitude')
plt.ylabel('Max Temperature (F)')
plt.xlabel('Latitude')
# Out:
# Text(0.5, 0, 'Latitude')

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
y_hum = clean_df['humidity']
plt.scatter(x_lat, y_hum, marker='o', facecolors='Green', edgecolors='black', s=50, alpha=0.85)
plt.title('Humidity vs. Latitude')
plt.ylabel('Humidity (%)')
plt.xlabel('Latitude')
plt.grid()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
y_cloud = clean_df['cloudiness']
plt.scatter(x_lat, y_cloud, marker='o', facecolors="deepskyblue", edgecolors='black', s=50, alpha=0.8)
plt.grid()
plt.title('Cloudiness vs. Latitude')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
# Out:
# Text(0, 0.5, 'Cloudiness (%)')

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
y_wind = clean_df['wind speed']
plt.scatter(x_lat, y_wind, marker='o', facecolors="lightsteelblue", edgecolors='black', s=50, alpha=0.85)
plt.grid()
plt.title('Wind Speed vs. Latitude')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
# Out:
# Text(0, 0.5, 'Wind Speed (mph)')

# %% [markdown]
# ## Linear Regression

# %%
# Creating seperate dataframes for Northern and Southern Hemisphere
# using .loc
# print results
n_hemisphere_data = clean_df.loc[clean_df['lat'] >= 0]
print('Northern Hemisphere')
print('----------------------------')
print(n_hemisphere_data.head())
print(n_hemisphere_data.count())
print('---------------------------')
print('Southern Hemisphere')
print('-----------------------------')
s_hemisphere_data = clean_df.loc[clean_df['lat'] < 0]
print(s_hemisphere_data.head())
print(s_hemisphere_data.count())
# Out:
# Northern Hemisphere
# ----------------------------
#        city        lat         lng  max temperature  humidity  cloudiness  \
# 0     dhaka  23.786198   90.402615            82.38      78.0        40.0
# 1    kodiak  57.790000 -152.407222            56.71      88.0       100.0
# 2    dikson  73.508389   80.512382            40.98      96.0       100.0
# 6    albany  42.651167  -73.754968            88.56      48.0        20.0
# 10  magrath  49.420320 -112.863749            87.53      42.0        59.0
#
#     wind speed country          date
# 0         4.61      BD  1.659133e+09
# 1        10.36      US  1.659133e+09
# 2        16.42      RU  1.659133e+09
# 6        12.66      US  1.659133e+09
# 10        3.44      CA  1.659134e+09
# city               421
# lat                421
# lng                421
# max temperature    421
# humidity           421
# cloudiness         421
# wind speed         421
# country            421
# date               421
# dtype: int64
# ---------------------------
# Southern Hemisphere
# -----------------------------
#           city        lat         lng  max temperature  humidity  cloudiness  \
# 3        luwuk  -0.952823  122.788020            75.42      94.0        99.0
# 4  port alfred -33.598184   26.891477            59.22      79.0        15.0
# 5      ushuaia -54.806116  -68.318497            38.89      56.0       100.0
# 7      rikitea -23.122954 -134.968014            73.20      72.0         9.0
# 8      vaitupu  -7.476946  178.680784            82.26      73.0        94.0
#
#    wind speed country          date
# 3        3.98      ID  1.659133e+09
# 4       12.71      ZA  1.659133e+09
# 5       23.02      AR  1.659133e+09
# 7       18.70      PF  1.659134e+09
# 8       18.88      TV  1.659134e+09
# city               170
# lat                170
# lng                170
# max temperature    170
# humidity           170
# cloudiness         170
# wind speed         170
# country            170
# date               170
# dtype: int64

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# values for regression
print('Northern Hemisphere - Max Temp vs. Latitude Linear Regression')
# x value (north hemisphere latitudes)
x_nh_lat = n_hemisphere_data['lat']
# y value (north hemispher max temps)
y_nh_maxtemp = n_hemisphere_data['max temperature']

# regression values (slope, intercept, rvalue, pvalue, stderr)
nh_mt_slope, nh_mt_int, nh_mt_r, nh_mt_p, nh_mt_stderr = linregress(x_nh_lat, y_nh_maxtemp)
nh_mt_fit = nh_mt_slope * x_nh_lat + nh_mt_int
nh_mt_eq = f'y = {round(nh_mt_slope,2)}x + {round(nh_mt_int,2)}'
print(f'Linear Regression Equation: {nh_mt_eq}')
nh_mt_correlation = st.pearsonr(x_nh_lat,y_nh_maxtemp)
print(f'Correlation: {nh_mt_correlation[0]}')

# plotting

# scatter
plt.scatter(x_nh_lat, y_nh_maxtemp, marker='o', facecolors='firebrick', edgecolors='black', s=50, alpha=0.75)
plt.grid()
plt.title('Northern Hemisphere - Max Temp vs. Latitude')
plt.xlabel('Latitude')
plt.ylabel('Max Temp (F)')

# plotting equation line
plt.plot(x_nh_lat, nh_mt_fit, 'k--')
plt.annotate(nh_mt_eq, (10,40))
# Out:
# Northern Hemisphere - Max Temp vs. Latitude Linear Regression
# Linear Regression Equation: y = -0.46x + 90.39
# Correlation: -0.6738010235908101
# Text(10, 40, 'y = -0.46x + 90.39')

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
